# %% [markdown]
# # RECOMMENDATION

# %% [markdown]
# ### The objective of this notebook is to implement a recommendation system to increase customer sales and retention.

# %% [markdown]
# # Installation of necessary packages and libraries

# %%
pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\ash\anaconda3\lib\site-packages (2.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in c:\users\ash\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\ash\anaconda3\lib\site-packages (from scikit-surprise) (1.0.1)
# Requirement already satisfied: numpy>=1.11.2 in c:\users\ash\anaconda3\lib\site-packages (from scikit-surprise) (1.20.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\ash\anaconda3\lib\site-packages (from scikit-surprise) (1.6.2)
# Requirement already satisfied: six>=1.10.0 in c:\users\ash\anaconda3\lib\site-packages (from scikit-surprise) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from collections import defaultdict

import psycopg2 as pg
import pandas.io.sql as pd_sql
from psycopg2 import connect
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

from sqlalchemy import create_engine

from scipy import stats

from surprise import NormalPredictor, Reader, Dataset, accuracy, SVD, SVDpp, KNNBasic, CoClustering, SlopeOne
from surprise.model_selection import cross_validate, KFold, GridSearchCV, train_test_split


from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error


import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import math
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Reading the dataset

# %%
import os
olist_combined = pd.read_csv('C:\OLIST\OlistRecommenderDataProductName.csv', low_memory=False)
#olist_combined = pd.read_csv('C:\OLIST\recommendation\OlistRecommenderDataProductName.csv')

# %%
olist_combined.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'order_id', 'payment_sequential',
#        'payment_type', 'payment_installments', 'payment_value', 'order_status',
#        'order_purchase_timestamp', 'order_estimated_delivery_date',
#        'order_item_id', 'shipping_limit_date', 'price', 'freight_value',
#        'product_id', 'product_category_name', 'product_category_name_english',
#        'product_name_lenght', 'product_description_lenght',
#        'product_photos_qty', 'product_weight_g', 'product_length_cm',
#        'product_height_cm', 'product_width_cm', 'seller_zip_code_prefix',
#        'seller_id', 'seller_city', 'seller_state', 'customer_id',
#        'customer_unique_id', 'customer_zip_code_prefix', 'customer_city',
#        'customer_state', 'review_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp', 'total_payment', 'product_name',
#        'Product Category'],
#       dtype='object')

# %% [markdown]
# # Creation of total_payment_value

# %% [markdown]
# ### Few purchases are with vouchers which inturn splits into may lines of smaller payments. therefore to normalise the remaining data we have combined them into total_payment_value

# %%
def create_total_payment_value(data):
    data['total_payment'] = data['payment_value'].groupby(data['order_id']).transform('sum')
    data= data.drop('payment_value', axis=1)
    return data

# %%
def duplicates(data):
    """
    Prints the number of duplicates in the input dataset, removes duplicate values keeping only the 
    first entry, and returns a dataset with no duplicate values.
    """
    
    # Confirm number of duplicate rows
    print(f"There are {data.duplicated().sum()} duplicate rows.")

    # Remove any duplicates, keeping only the first entry
    data = data.drop_duplicates(keep='first')

    # Confirm duplicates were removed correctly
    print(f"After dropping, there are {data.duplicated().sum()} duplicate rows.")
    print(f"Returned dataset has {data.shape[0]} rows")
    
    return data

# %%
olist_data = create_total_payment_value(olist_combined)

# %% [markdown]
# # Checking for duplicates

# %%
olist_data = duplicates(olist_data)
# Out:
# There are 0 duplicate rows.
# After dropping, there are 0 duplicate rows.
# Returned dataset has 100851 rows

# %%
olist_data.describe([.75,.99])
# Out:
#           Unnamed: 0   Unnamed: 0.1  payment_sequential  payment_installments  \
# count  100851.000000  100851.000000       100851.000000         100851.000000
# mean    50425.000000   50425.000000            1.091858              2.939346
# std     29113.320336   29113.320336            0.712193              2.776261
# min         0.000000       0.000000            1.000000              0.000000
# 50%     50425.000000   50425.000000            1.000000              2.000000
# 75%     75637.500000   75637.500000            1.000000              4.000000
# 99%     99841.500000   99841.500000            3.000000             10.000000
# max    100850.000000  100850.000000           29.000000             24.000000
#
#        order_item_id          price  freight_value  product_name_lenght  \
# count  100851.000000  100851.000000  100851.000000         99362.000000
# mean        1.198719     120.322252      20.025920            48.753668
# std         0.711144     184.124366      15.860981            10.039675
# min         1.000000       0.850000       0.000000             5.000000
# 50%         1.000000      74.900000      16.310000            52.000000
# 75%         1.000000     134.900000      21.180000            57.000000
# 99%         4.000000     889.550000      85.255000            63.000000
# max        21.000000    6735.000000     409.680000            76.000000
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# count                99362.000000        99362.000000     100835.000000
# mean                   785.137326            2.200187       2104.193157
# std                    652.062160            1.713838       3767.479959
# min                      4.000000            1.000000          0.000000
# 50%                    600.000000            1.000000        700.000000
# 75%                    985.000000            3.000000       1800.000000
# 99%                   3417.170000            8.000000      18350.000000
# max                   3985.000000           20.000000      40425.000000
#
#        product_length_cm  product_height_cm  product_width_cm  \
# count      100835.000000      100835.000000     100835.000000
# mean           30.242922          16.639213         23.070313
# std            16.162962          13.443692         11.747344
# min             7.000000           2.000000          6.000000
# 50%            25.000000          13.000000         20.000000
# 75%            38.000000          20.000000         30.000000
# 99%            95.000000          65.000000         62.000000
# max           105.000000         105.000000        118.000000
#
#        seller_zip_code_prefix    customer_id  customer_zip_code_prefix  \
# count           100851.000000  100851.000000             100851.000000
# mean             24480.424696   49637.209834              35046.036747
# std              27597.645374   28617.862645              29812.485840
# min               1001.000000       1.000000               1003.000000
# 50%              13613.000000   49633.000000              24240.000000
# 75%              28630.000000   74404.500000              58410.000000
# 99%              93542.000000   98416.500000              97574.500000
# max              99730.000000   99440.000000              99990.000000
#
#         review_score  total_payment
# count  100851.000000  100851.000000
# mean        4.013049     358.960980
# std         1.402232    1671.336309
# min         1.000000       9.590000
# 50%         5.000000     127.170000
# 75%         5.000000     259.360000
# 99%         5.000000    3791.460000
# max         5.000000  109312.640000

# %% [markdown]
# # Recommender related EDA :

# %% [markdown]
# ## 1)Consumer Centric

# %%
olist_blue  = '#007FAA'
olist_green = '#0CC78B'

# %%
def general_customer_info(data):
    """Returns number of unique and repeat customers in the dataset."""
    print("Number of unique customers:", data.customer_unique_id.nunique())
    
    customer_count = data.customer_unique_id.value_counts()
    print("Number of repeat customers:", customer_count[customer_count > 1].count())

    return

general_customer_info(olist_data)
# Out:
# Number of unique customers: 81662
# Number of repeat customers: 12097

# %% [markdown]
# ### Therefore, we can infer that no.of unique customers > no.of repeating customers

# %% [markdown]
# # Description of distribution of orders per customer

# %%
def order_per_consumer(data):
    return data.groupby('customer_unique_id')['order_id'].agg(['count'])
    
orders_per_consumer = order_per_consumer(olist_data)

fig = plt.figure(figsize=(32,10))
ax = fig.gca()
sns.countplot(orders_per_consumer['count'], color=olist_blue)
ax.set(xlabel='Number of Orders', ylabel='Count', title='Distribution of Orders Per Consumer');

# %% [markdown]
# # Analysis of location of customers throughout Brazil

# %%
def customer_geography(data):
    customer_locations = pd.DataFrame(data.customer_city.value_counts().sort_values(ascending=False))
    customer_locations = customer_locations(olist_data).reset_index().rename(columns={'index': 'city', 'customer_city':'num_customers'})
    
    print(f"There are {customer_locations.city.nunique()} unique customer cities.\n")
    
    top_ten_cities = customer_locations.city[:10]
    customers_in_top_ten_cities = round(customer_locations.num_customers[:10].sum()/customer_locations.num_customers.sum()*100,2)

    print(f"The majority of customers, {customers_in_top_ten_cities} percent, live in the top ten cities.\n")

    return customer_locations, top_ten_cities

# %%
customer_locations = pd.DataFrame(olist_data.customer_city.value_counts().sort_values(ascending=False))

# %%
customer_locations = customer_locations.reset_index().rename(columns={'index': 'city', 'customer_city':'num_customers'})

# %%
customer_locations
# Out:
#                       city  num_customers
# 0                sao paulo          15849
# 1           rio de janeiro           7192
# 2           belo horizonte           2777
# 3                 brasilia           2096
# 4                 curitiba           1523
# ...                    ...            ...
# 3927               igapora              1
# 3928              grupiara              1
# 3929             jaguaracu              1
# 3930              baturite              1
# 3931  planaltina do parana              1
#
# [3932 rows x 2 columns]

# %%
top_ten_cities = customer_locations.city[:10]

# %%
# plot top cities
fig = plt.figure(figsize=(12,5))
ax = fig.gca()
sns.barplot(x=customer_locations.num_customers[:10], y=top_ten_cities, ax=ax, color=olist_blue)
ax.set(xlabel='Number of Customers', ylabel='City', title='Top ten cities for Olist Customers');

# %%
customers_in_top_ten_cities = round(customer_locations.num_customers[:10].sum()/customer_locations.num_customers.sum()*100,2)
print(f"The majority of customers, {customers_in_top_ten_cities} percent, live in the top ten cities.\n")
# Out:
# The majority of customers, 35.52 percent, live in the top ten cities.

# %% [markdown]
# ### Thus, after sorting the fequent customer locations in descending order, then plotting the top 10 cities on in, we can infel that majority of the customers are from the top 10 cities in Brazil. Thus it can be concluded to focus more on these place in order to maximize the sales and optimize the strategies in other places in order to increase the rate of sales

# %% [markdown]
# # 2) Order centric :

# %%
def items_per_order(data):
    item_orders = data.groupby('order_id').product_id.agg(['count']).sort_values(by='count')
    avg_items_per_order = item_orders.mean()
    print(f"Average number of items per order: {avg_items_per_order}")
    return avg_items_per_order

avg_items_per_order = items_per_order(olist_data)
# Out:
# Average number of items per order: count    1.199351
# dtype: float64

# %% [markdown]
# # Analysis on the payment methods

# %%
def payment_types(data):
    return data.payment_type.value_counts()

payment_types = payment_types(olist_data)

fig = plt.figure(figsize=(6,5))
ax = fig.gca()
sns.barplot(x=payment_types.index, y=payment_types.values, color=olist_blue)
ax.set(xlabel='Number of Customers', ylabel='Payment Type', title='Distrobution of Payment Types');

# %% [markdown]
# ### From the bar graph we can conclude that payments via credit card is the highest and debit card is the lowest

# %% [markdown]
# # Analysis on the installments

# %%
plt.figure(figsize=(8,5))
plt.hist(olist_data.payment_installments, color=olist_blue, bins=20)
plt.xlabel('Number of Installments')
plt.ylabel('Count')
plt.title('Distrobution of Payment Installments');

# %%
def sales_per_seller(data):
    """
    Returns the average number of sales per Olist seller, the magnitude of the top 10 sellers,
    and the number of sales that the top seller has made.
    """
    
    sales_per_seller = data.groupby('seller_id')['order_id'].count()
    print(f"Avg. number of sales per seller: {sales_per_seller.mean()}\n")
    
    top_ten_sellers = sales_per_seller.sort_values(ascending=False)[:10]
    sales_in_top_ten_sellers = round(top_ten_sellers.values.sum()/sales_per_seller.values.sum()*100,2)

    print(f"The top 10 sellers account for {sales_in_top_ten_sellers} percent of the total sales\n")

    print(f"The top seller has {top_ten_sellers[0]} sales")

    return sales_per_seller

sales_per_seller = sales_per_seller(olist_data)


plt.figure(figsize=(8,5))
plt.hist(sales_per_seller, bins=50, color=olist_blue)
plt.xlabel('Number of Sales')
plt.ylabel('Count')
plt.title('Number of Sales Per Seller');
# Out:
# Avg. number of sales per seller: 33.69562312061477
#
# The top 10 sellers account for 14.18 percent of the total sales
#
# The top seller has 1847 sales

# %%
# Average product cost
def product_sales_info(data, olist_blue):
    """
    Identifies number of unique products sold at olist, the average price per product, the
    average number of sales per product. and a list of the top ten products. Plots the 
    distrobution of sales per product.
    """
    
    print(f"Number of unique products: {data.product_name.nunique()}\n")
    print(f"Average price per product: {data.price.mean()}\n")
    
    number_prod_sold = data.product_name.value_counts()
    print(f"Average sales per product: {np.mean(number_prod_sold)}\n")
    
    # top products
    top_ten_products = number_prod_sold[:10]
    print(f"Top ten selling products:\n{top_ten_products}\n")
    print(f"The top ten selling products account for {round(top_ten_products.values.sum()/number_prod_sold.values.sum()*100,2)} percent of the product sold.\n")

    p_q_97 = number_prod_sold.quantile(.97)
    products_q_97 = number_prod_sold[number_prod_sold < p_q_97]

    plt.figure(figsize=(8,5))
    plt.hist(products_q_97, bins=10, color=olist_blue)
    plt.xlabel('Number of Sales')
    plt.ylabel('Count')
    plt.title('Number of Sales Per Seller (without top 3% removed)');
    
    return

product_sales_info(olist_data, olist_blue)
# Out:
# Number of unique products: 29941
#
# Average price per product: 120.32225183698651
#
# Average sales per product: 3.3683243712634847
#
# Top ten selling products:
# Toasted Buttercrisp Crackers                               470
# Stainless Steel Water Bottle With Sport Cap, Aqua Color    459
# Clotted Cream, English Luxury                              406
# Corn Pops Cereal                                           355
# 8\" Pepperoni Pizza                                        334
# Crystals Lavender Blossom In-Wash Fragrance Booster        328
# Sheep Milk Original Plain Kefir                            304
# Traditional Non-Alcoholic Egg Nog                          274
# Original Creole Seasoning                                  247
# Max Cockroach Killer                                       240
# Name: product_name, dtype: int64
#
# The top ten selling products account for 3.39 percent of the product sold.

# %% [markdown]
# ### The above cell provides us the with top 10 most sold productS along with respective counts. It can be inferred that these products are mostly preferred by the customers.

# %% [markdown]
# # Analysis on the product reviews

# %% [markdown]
# ### The analysis on the product reviews depends on the no.of reviews and ratings provided by the customer

# %%
def product_reviews(data):
    reviewed_products = data.groupby('product_id')['review_score'].agg(['mean', 'count']).reset_index()
    top_ten_reviewed_products = reviewed_products.sort_values(by=['mean','count'],ascending=False)[:10]

    print(f"The top reviewed products are\n {top_ten_reviewed_products}")
    
    return reviewed_products

reviewed_products = product_reviews(olist_data)


plt.figure(figsize=(8,5))
plt.hist(reviewed_products['mean'], bins=10, color=olist_blue)
plt.xlabel('Distribution of Product Reviews')
plt.ylabel('Count')
plt.title('Review Score');
# Out:
# The top reviewed products are
#        product_id  mean  count
# 4437      P04885   5.0     44
# 27644     P30441   5.0     38
# 20274     P22328   5.0     21
# 1513      P01672   5.0     17
# 906       P01002   5.0     15
# 3804      P04179   5.0     15
# 4595      P05052   5.0     15
# 13506     P14877   5.0     14
# 23830     P26245   5.0     14
# 27816     P30633   5.0     14

# %%
fig = plt.figure(figsize=(6,5))
ax = sns.jointplot(x=reviewed_products['mean'], y=reviewed_products['count'], data=reviewed_products);

# %%
olist_data.rename(columns={'Product Category':'product_category_new'}, inplace=True)

# %%
olist_data
# Out:
#         Unnamed: 0  Unnamed: 0.1 order_id  payment_sequential payment_type  \
# 0                0             0  ON53096                   1  credit_card
# 1                1             1  ON99582                   1       boleto
# 2                2             2  ON17222                   1  credit_card
# 3                3             3  ON77806                   1  credit_card
# 4                4             4  ON03948                   1  credit_card
# ...            ...           ...      ...                 ...          ...
# 100846      100846        100846  ON20609                   1  credit_card
# 100847      100847        100847  ON47795                   1  credit_card
# 100848      100848        100848  ON12593                   1  credit_card
# 100849      100849        100849  ON17375                   1  credit_card
# 100850      100850        100850  ON72563                   1  credit_card
#
#         payment_installments order_status order_purchase_timestamp  \
# 0                          2    delivered           7/2/2018 18:05
# 1                          1    delivered         10/16/2017 19:15
# 2                          5    delivered          5/25/2017 22:40
# 3                          2    delivered          1/12/2018 10:02
# 4                          5    delivered          4/20/2018 12:56
# ...                      ...          ...                      ...
# 100846                     7    delivered          2/28/2018 10:14
# 100847                     6    delivered          4/20/2017 13:07
# 100848                     6    delivered          4/23/2017 16:59
# 100849                     8    delivered          2/18/2018 17:33
# 100850                     1    delivered           5/4/2018 13:18
#
#        order_estimated_delivery_date  order_item_id  ... customer_state  \
# 0                     7/25/2018 0:00              1  ...             SP
# 1                    11/16/2017 0:00              1  ...             PA
# 2                     6/21/2017 0:00              1  ...             MG
# 3                      2/6/2018 0:00              1  ...             MG
# 4                     5/15/2018 0:00              1  ...             RJ
# ...                              ...            ...  ...            ...
# 100846                3/27/2018 0:00              1  ...             RJ
# 100847                5/15/2017 0:00              1  ...             RJ
# 100848                5/17/2017 0:00              1  ...             SP
# 100849                3/12/2018 0:00              1  ...             RJ
# 100850                5/23/2018 0:00              1  ...             MG
#
#         review_id  review_score review_comment_title  \
# 0         PR43983             4                  NaN
# 1         PR17887             1                  NaN
# 2         PR91499             5                  NaN
# 3         PR91027             5                  NaN
# 4         PR99382             1        não recomendo
# ...           ...           ...                  ...
# 100846    PR28493             5                  NaN
# 100847    PR61174             5                  NaN
# 100848    PR73958             5                  NaN
# 100849    PR43440             3                  NaN
# 100850    PR60184             5                  NaN
#
#                                    review_comment_message  \
# 0                                                     NaN
# 1                                                     NaN
# 2       Estou super confuso sobre outra compra que fiz...
# 3                                                     NaN
# 4       Sempre comprei nas Lojas lannister pela entreg...
# ...                                                   ...
# 100846       otimos produtos \r\ntudo ok\r\nshow de bola
# 100847                                                NaN
# 100848                                                NaN
# 100849  Excelente produto, correto, bem embalado mas c...
# 100850                                                NaN
#
#        review_creation_date  review_answer_timestamp  total_payment  \
# 0            7/12/2018 0:00          7/12/2018 13:01          70.97
# 1            11/7/2017 0:00          11/7/2017 21:17          81.76
# 2             6/6/2017 0:00           6/6/2017 23:56         114.80
# 3            1/20/2018 0:00          1/24/2018 14:55         110.63
# 4            5/17/2018 0:00          5/17/2018 15:51         269.29
# ...                     ...                      ...            ...
# 100846       3/27/2018 0:00           4/3/2018 14:51          96.80
# 100847        5/4/2017 0:00           5/5/2017 10:50          68.55
# 100848        5/4/2017 0:00           5/7/2017 11:30         237.14
# 100849        3/6/2018 0:00           3/6/2018 15:39         165.80
# 100850       5/13/2018 0:00           5/14/2018 1:43          69.90
#
#                                  product_name  product_category_new
# 0                             Utility Lighter        more household
# 1                          Syrup, Maple Creme        more household
# 2           Vegan Alfredo Sauce Arugula Pesto        more household
# 3                            Disposal Cleaner        more household
# 4                         Light String Cheese        more household
# ...                                       ...                   ...
# 100846       Frappuccino Chilled Coffee Drink          Hand Luggage
# 100847                            Bimini cap           frozen meals
# 100848           Borderless messenger shorts          Apple Macbook
# 100849  Tall Kitchen Bags, Handle-Tie, 13 Gal              Perfumes
# 100850           Toasted Buttercrisp Crackers        frozen produce
#
# [100851 rows x 41 columns]

# %% [markdown]
# # Analysis on the categories of the products

# %%
def product_categories():
    print(f"There are {olist_data.product_category_new.nunique()} categories")

    top_ten_categories = olist_data.product_category_new.value_counts().sort_values(ascending=False)[:10]

    plt.figure(figsize=(8,5))
    ax = sns.barplot(top_ten_categories.values, top_ten_categories.index, color=olist_blue)
    ax.set(xlabel='Count', ylabel='Product Category', title='Top Ten Product Categories');
    
    return

product_categories()
# Out:
# There are 133 categories

# %% [markdown]
# # Implementation of feature engineering

# %% [markdown]
# ### The customers are categorized as  a repeat customer or new customers.
#
# ### REPEAT CUSTOMERS : Collaborative filtering is used to recommend products. Results are measured by how many predictions are right using the recommender vs. how many are right when just recommending the most popular item.
# ### NEW CUSTOMER : Recommendation based on customer segmentation

# %%
def repeat_and_first_time(data):
    """Takes in a dataset and returns back the dataset with only repeated customers"""
    repeaters = data.groupby('customer_unique_id').filter(lambda x: len(x) > 1)
    first_timers = data.groupby('customer_unique_id').filter(lambda x: len(x) == 1)
    
    # Save datasets for easier accessing
    repeater_data.to_csv('repeater_data.csv')
    first_timer_data.to_csv('first_timer_data.csv')
    
    print("Shape of repeater dataset:", repeater_data.shape)

    print("Shape of first timer dataset:", first_timer_data.shape)

    return repeaters, first_timers

# %%
repeater_data =  olist_data.groupby('customer_unique_id').filter(lambda x: len(x) > 1)

# %%
first_timers = olist_data.groupby('customer_unique_id').filter(lambda x: len(x) == 1)

# %%
repeater_data.to_csv('repeater_data.csv')
first_timers.to_csv('first_timer_data.csv')

# %%
def regenerate_dataset_with_indicators(repeater_data, first_timers):
    repeater_data['repeater'] = 1
    first_timers['repeater'] = 0
    
    full_df = pd.concat((repeater_data, first_timers), axis=0).reset_index()
    print("full_df shape:", full_df.shape)
    return full_df

# %%
full_df = regenerate_dataset_with_indicators(repeater_data, first_timers)
# Out:
# full_df shape: (100851, 43)

# %% [markdown]
# # RECOMMENDATIONS FOR REPEAT CUSTOMERS

# %% [markdown]
# ### The full data set is filtered down to only repeat customers.
# ### The goal is to predict the customers review on a product they have not purchased.
# ### Four methods are tested and compared: using only purchase count, normalized purchase frequency, user ratings matrix, and normalized user ratings matrix.

# %% [markdown]
# ## Method 1 : Purchase Count

# %%
def create_puchase_count_df(data):
    """
    Creates a dataset with customer_unique_id, _productId, and purchase count for that 
    user-product combination.
    """
    purchase_count = pd.melt(data.set_index('customer_unique_id')['product_id'].apply(pd.Series).reset_index(), 
                 id_vars=['customer_unique_id'],
                 value_name='product_id')
    purchase_count = purchase_count.dropna().drop(['variable'], axis=1)
    purchase_count = purchase_count.groupby(['customer_unique_id', 'product_id']).agg({'product_id': 'count'})
    purchase_count = purchase_count.rename(columns={'product_id': 'estimator'}).reset_index()
    purchase_count = purchase_count.rename(columns={'product_id': 'productId'})
    
    return purchase_count

# %%
purchase_count_df = create_puchase_count_df(repeater_data)

# %%
purchase_count_df.head()
# Out:
#   customer_unique_id productId  estimator
# 0             C00006    P12312          1
# 1             C00006    P28372          1
# 2             C00010    P02020          2
# 3             C00020    P24082          2
# 4             C00039    P31888          2

# %%
len(purchase_count_df)
# Out:
# 17420

# %%
purchase_count_df.shape
# Out:
# (17420, 3)

# %%
new = olist_data[['product_id','product_name']]

# %%
new.drop_duplicates(subset=['product_id'],inplace=True)

# %%
new.shape
# Out:
# (29941, 2)

# %%
new.rename(columns={'product_id':'productId'}, inplace=True)

# %%
new
# Out:
#        productId                       product_name
# 0         P20466                    Utility Lighter
# 1         P04472                 Syrup, Maple Creme
# 2         P27039  Vegan Alfredo Sauce Arugula Pesto
# 3         P00173                   Disposal Cleaner
# 4         P24387                Light String Cheese
# ...          ...                                ...
# 100836    P12211                   Baby synch vest
# 100839    P10817               Baby tag you're it t
# 100840    P24717              L/s sol patrol shirt
# 100847    P21984                        Bimini cap
# 100848    P26473       Borderless messenger shorts
#
# [29941 rows x 2 columns]

# %%
purchase_count_df_new = pd.merge(purchase_count_df, new, on='productId', how='left')

# %%
purchase_count_df_new
# Out:
#       customer_unique_id productId  estimator  \
# 0                 C00006    P12312          1
# 1                 C00006    P28372          1
# 2                 C00010    P02020          2
# 3                 C00020    P24082          2
# 4                 C00039    P31888          2
# ...                  ...       ...        ...
# 17415             C96954    P01013          2
# 17416             C96954    P18418          2
# 17417             C96985    P05269          1
# 17418             C96985    P08821          1
# 17419             C96995    P02127          2
#
#                                             product_name
# 0                              Organic Ginger Herbal Tea
# 1            HE Turbo Powder Original  Laundry Detergent
# 2                                            Elsa tunic
# 3                  Chocolate Peanut Butter Builder's Bar
# 4                                  Quinoa Chips Barbeque
# ...                                                  ...
# 17415                            Ice Shine Pro-V Shampoo
# 17416         Lemongrass Basil Chicken With Jasmine Rice
# 17417                                   100% Lemon Juice
# 17418                Grill Shakers Steak Seasoning Blend
# 17419  Malt Vinegar & Sea Salt Kettle Cooked Potato C...
#
# [17420 rows x 4 columns]

# %% [markdown]
# ## Method 2: Normalize Purchase Frequency

# %%
def normalize_purchase_count(data):
    """
    Creates a dataset with customer_unique_id, _productId, and purchase count for that 
    user-product combination, and then normalized the data. 
    """
    count_matrix = pd.pivot_table(data, values='estimator', index='customer_unique_id', columns='productId')
    
    count_matrix_norm = (count_matrix-count_matrix.min())/(count_matrix.max()-count_matrix.min())
    count_matrix_norm = count_matrix_norm.reset_index()
    count_matrix_norm.index.names = ['scaled_purchase_freq']
    
    normalized_count_matrix = pd.melt(count_matrix_norm, id_vars=['customer_unique_id'], value_name='estimator').dropna()
    
    return normalized_count_matrix

# %%
normalized_purchase_count_df = normalize_purchase_count(purchase_count_df_new)

# %%
normalized_purchase_count_df.head()
# Out:
#        customer_unique_id productId  estimator
# 48939              C04022    P00018   1.000000
# 56104              C62271    P00018   0.000000
# 109840             C07391    P00035   0.000000
# 115566             C54057    P00035   0.333333
# 115966             C57292    P00035   0.333333

# %%
normalized_purchase_count_df_new = pd.merge(normalized_purchase_count_df, new, on='productId', how='left')

# %%
normalized_purchase_count_df_new.head()
# Out:
#   customer_unique_id productId  estimator  \
# 0             C04022    P00018   1.000000
# 1             C62271    P00018   0.000000
# 2             C07391    P00035   0.000000
# 3             C54057    P00035   0.333333
# 4             C57292    P00035   0.333333
#
#                               product_name
# 0                  Multigrain Penne Rigate
# 1                  Multigrain Penne Rigate
# 2  Butternut Squash Pear Stage 2 Baby Food
# 3  Butternut Squash Pear Stage 2 Baby Food
# 4  Butternut Squash Pear Stage 2 Baby Food

# %% [markdown]
# ## Method 3: User Ratings Matrix

# %%
def create_user_ratings_df(data):
    """Takes in a dataset and aggregates the review score for each product within each
    customer_unique_id."""
    user_prod_reviewscore_data = data.groupby(['customer_unique_id','product_id']
                                             )['review_score'].agg(['mean']).reset_index()
    
    user_prod_reviewscore_data = user_prod_reviewscore_data.rename({'mean':'estimator', 'product_id':'productId'}, 
                                                                   axis=1)
    
#     user_prod_reviewscore_data.avg_rating = user_prod_reviewscore_data.avg_rating.apply(lambda x: 1)
    
    return user_prod_reviewscore_data

# %%
user_ratings_df = create_user_ratings_df(repeater_data)

# %%
user_ratings_df.head()
# Out:
#   customer_unique_id productId  estimator
# 0             C00006    P12312        3.0
# 1             C00006    P28372        4.0
# 2             C00010    P02020        4.0
# 3             C00020    P24082        4.0
# 4             C00039    P31888        4.0

# %%
user_ratings_df.shape
# Out:
# (17420, 3)

# %%
user_ratings_df_new = pd.merge(user_ratings_df, new, on='productId', how='left')

# %%
user_ratings_df_new.head()
# Out:
#   customer_unique_id productId  estimator  \
# 0             C00006    P12312        3.0
# 1             C00006    P28372        4.0
# 2             C00010    P02020        4.0
# 3             C00020    P24082        4.0
# 4             C00039    P31888        4.0
#
#                                   product_name
# 0                    Organic Ginger Herbal Tea
# 1  HE Turbo Powder Original  Laundry Detergent
# 2                                  Elsa tunic
# 3        Chocolate Peanut Butter Builder's Bar
# 4                        Quinoa Chips Barbeque

# %%
user_ratings_df_new.shape
# Out:
# (17420, 4)

# %% [markdown]
# ## Method 4: Normalized User Ratings Matrix

# %%
def normalize_purchase_count(data):
    """Creates a user-ratings matrix but normalizes the ratings data."""
    ratings_matrix = pd.pivot_table(data, values='estimator', index='customer_unique_id', columns='productId')
    
    ratings_matrix_norm = (ratings_matrix-ratings_matrix.min())/(ratings_matrix.max()-ratings_matrix.min())
    ratings_matrix_norm = ratings_matrix_norm.reset_index()
    ratings_matrix_norm.index.names = ['estimator']
    
    normalized_ratings_matrix = pd.melt(ratings_matrix_norm, id_vars=['customer_unique_id'], value_name='estimator').dropna()
    
    return normalized_ratings_matrix

# %%
normalized_user_ratings_df = normalize_purchase_count(user_ratings_df_new)

# %%
normalized_user_ratings_df.head()
# Out:
#        customer_unique_id productId  estimator
# 48939              C04022    P00018        1.0
# 56104              C62271    P00018        0.0
# 109840             C07391    P00035        0.5
# 115566             C54057    P00035        1.0
# 115966             C57292    P00035        0.0

# %%
normalized_user_ratings_df.shape
# Out:
# (8150, 3)

# %%
normalized_user_ratings_df_new = pd.merge(normalized_user_ratings_df, new, on='productId', how='left')

# %%
normalized_user_ratings_df_new.head()
# Out:
#   customer_unique_id productId  estimator  \
# 0             C04022    P00018        1.0
# 1             C62271    P00018        0.0
# 2             C07391    P00035        0.5
# 3             C54057    P00035        1.0
# 4             C57292    P00035        0.0
#
#                               product_name
# 0                  Multigrain Penne Rigate
# 1                  Multigrain Penne Rigate
# 2  Butternut Squash Pear Stage 2 Baby Food
# 3  Butternut Squash Pear Stage 2 Baby Food
# 4  Butternut Squash Pear Stage 2 Baby Food

# %%
normalized_user_ratings_df_new.shape
# Out:
# (8150, 4)

# %% [markdown]
# # Model Selection

# %% [markdown]
# ### Different models are tested against each of the datasets created above. The model with the lowest RMSE is selected for additional tuning.

# %%
def surprise_df(data):
    
    scale = (data.estimator.min(), data.estimator.max())
    reader = Reader(rating_scale=scale)

    # The columns must correspond to user id, item id and ratings (in that order).
    df = Dataset.load_from_df(data[['customer_unique_id','productId','estimator']], reader)
    
    return df

# Split data into 5 kfolds
kf = KFold(n_splits=5, shuffle=True, random_state=19)

# Helper function to test different types of collaborative filtering
def model_framework(train_data):
    
    test_df = surprise_df(train_data)
    
    normp_rmse, svd_rmse, knn_rmse, co_rmse, slope_rmse = [], [], [], [], []

    for trainset, testset in kf.split(test_df): #iterate through the folds.
        
        #baseline
        normp = NormalPredictor()
        normp.fit(trainset)
        normp_pred = normp.test(testset)
        normp_rmse.append(accuracy.rmse(normp_pred,verbose=False))
        
        #svd
        svd = SVD(n_factors=30, n_epochs=50,biased=True, lr_all=0.005, reg_all=0.4, verbose=False)
        svd.fit(trainset)
        svd_pred = svd.test(testset)
        svd_rmse.append(accuracy.rmse(svd_pred,verbose=False))
        
        #knn
        knn = KNNBasic(k=40,sim_options={'name': 'cosine', 'user_based': False}, verbose=False) 
        knn.fit(trainset)
        knn_pred = knn.test(testset)
        knn_rmse.append(accuracy.rmse(knn_pred,verbose=False))
        
        #co_clustering
        co = CoClustering(n_cltr_u=3,n_cltr_i=3,n_epochs=20)         
        co.fit(trainset)
        co_pred = co.test(testset)
        co_rmse.append(accuracy.rmse(co_pred,verbose=False))
        
        #slope_one
        slope = SlopeOne() 
        slope.fit(trainset)
        slope_pred = slope.test(testset)
        slope_rmse.append(accuracy.rmse(slope_pred,verbose=False))
    
    mean_rmses = [np.mean(normp_rmse),
                  np.mean(svd_rmse),
                  np.mean(knn_rmse),
                  np.mean(co_rmse),
                  np.mean(slope_rmse)]
    
    model_names = ['baseline', 'svd','knn','coclustering','slopeone']
    compare_df = pd.DataFrame(mean_rmses, index=model_names)
    
    return compare_df

# %%
def model_comparison(all_methods):
    comp_matrix = model_framework(all_methods[0]).transpose()
    print('Initial dataframe created.')
    
    for method in all_methods[1:]:
        temp_df = model_framework(method).transpose()
        comp_matrix = pd.concat((comp_matrix,temp_df), axis=0)
        print("Layer added to dataframe.")
        
    comp_matrix = comp_matrix.set_index([['purchase_count', 
                                       'norm_purchase_count', 
                                       'user_ratings', 
                                       'norm_user_ratings']])
    
    return comp_matrix

# %%
all_methods = [purchase_count_df_new, normalized_purchase_count_df_new, user_ratings_df_new, normalized_user_ratings_df_new]

# %%
comparison_matrix = model_comparison(all_methods)
# Out:
# Initial dataframe created.
# Layer added to dataframe.
# Layer added to dataframe.
# Layer added to dataframe.

# %% [markdown]
# ### Creating method_comparison column to indicate the performance of the models to be compared based on the dataset

# %%
comparison_matrix['best_score'] = comparison_matrix.min(axis=1)
comparison_matrix['method_comparison'] = 100*(1-(comparison_matrix.best_score/comparison_matrix.baseline)) 
comparison_matrix
# Out:
#                      baseline       svd       knn  coclustering  slopeone  \
# purchase_count       1.697843  1.262808  1.312143      1.324897  1.279862
# norm_purchase_count  0.552584  0.451295  0.435789      0.444512  0.426369
# user_ratings         1.973974  1.437542  1.518737      1.494172  1.420024
# norm_user_ratings    0.562372  0.463330  0.434360      0.448284  0.417947
#
#                      best_score  method_comparison
# purchase_count         1.262808          25.622794
# norm_purchase_count    0.426369          22.840880
# user_ratings           1.420024          28.062677
# norm_user_ratings      0.417947          25.681482

# %% [markdown]
# ### It can be inferred that user ratings (SVD) has good performance compared with others.
# ### Thus, we will leverage user rating matrix as it requires minimal computational expense and maximum variance.

# %% [markdown]
# # PERFORMING GRIDSEARCH

# %%
def gridsearch(data, model, param_grid):
    param_grid = param_grid
    gs = GridSearchCV(model, param_grid, measures=['rmse'], cv=5)
    gs.fit(data)
    
    new_params = gs.best_params['rmse']
    best_score = gs.best_score['rmse']
    
    print("Best score:", best_score)
    print("Best params:", new_params)
    
    return new_params, best_score

# %% [markdown]
# # Performing standard svd gridsearch

# %%
data = surprise_df(user_ratings_df_new)

svd_param_grid = {'n_factors': [25,50,100],'n_epochs': [20,30,50], 'lr_all': [0.002,0.005,0.01],
              'reg_all':[0.02,0.1, 0.4]}

svd_params, svd_score = gridsearch(data, SVD, svd_param_grid)
# Out:
# Best score: 1.3884000134204963
# Best params: {'n_factors': 25, 'n_epochs': 50, 'lr_all': 0.01, 'reg_all': 0.1}

# %%
svdpp_param_grid = {'n_factors': [10, 20, 50],'n_epochs': [20,30,50], 'lr_all': [0.002,0.007,0.01],
              'reg_all':[0.02,0.1, 0.4]}

svdpp_params, svdpp_score = gridsearch(data, SVDpp, svdpp_param_grid)
# Out:
# Best score: 1.3855093121876934
# Best params: {'n_factors': 10, 'n_epochs': 50, 'lr_all': 0.01, 'reg_all': 0.1}

# %%
def svd_model(data, model_list, model_names):
    all_scores = []
    
    for model in model_list:
        model_rmse = []
        model_mae = []
        
        for trainset, testset in kf.split(data): #iterate through the folds.

            mod = model
            mod.fit(trainset)
            pred = mod.test(testset)
            model_rmse.append(accuracy.rmse(pred,verbose=False))
            model_mae.append(accuracy.mae(pred,verbose=False))
            
        all_scores.append([np.mean(model_rmse), np.mean(model_mae)])
    
    results = pd.DataFrame(all_scores, index=model_names, columns=['rmse','mae'])
    
    return results

# %%
def svd_comparisons():
    # For comparison, baseline model
    random = NormalPredictor()

    # Standard SVD models
    tuned_svd = SVD(n_factors=svd_params['n_factors'], 
                    n_epochs=svd_params['n_epochs'],
                    lr_all=svd_params['lr_all'], 
                    reg_all=svd_params['reg_all'])

    standard_svd = SVD()

    # SVDpp moddels
    tuned_svdpp = SVDpp(n_factors=svdpp_params['n_factors'], 
                        n_epochs=svdpp_params['n_epochs'],
                        lr_all=svdpp_params['lr_all'], 
                        reg_all=svdpp_params['reg_all'])

    standard_svdpp = SVDpp()


    model_list = [random, tuned_svd, standard_svd, tuned_svdpp, standard_svdpp]
    model_names = ['random','tuned_svd','standard_svd','tuned_svdpp','standard_svdpp']

    return svd_model(data, model_list, model_names)

# %%
svd_comparison_df = svd_comparisons()
svd_comparison_df
# Out:
#                     rmse       mae
# random          1.981975  1.566458
# tuned_svd       1.390562  1.169656
# standard_svd    1.493774  1.290494
# tuned_svdpp     1.385461  1.163997
# standard_svdpp  1.471281  1.267183

# %%
svdpp_performance = 100*(1-(svd_comparison_df.loc['tuned_svdpp', 'rmse'] / svd_comparison_df.loc['random', 'rmse']))
print(f"Tuned SVDpp performed {svdpp_performance} better than baseline.")
# Out:
# Tuned SVDpp performed 30.096916395789584 better than baseline.

# %% [markdown]
# # Final Model of Repetative Customers

# %%
def create_user_ratings_df(data):
    """Takes in a dataset and aggregates the review score for each product within each
    customer_unique_id."""
    user_prod_reviewscore_data = data.groupby(['customer_unique_id','product_id']
                                             )['review_score'].agg(['mean']).reset_index()
    
    user_prod_reviewscore_data = user_prod_reviewscore_data.rename({'mean':'estimator', 'product_id':'productId'}, 
                                                                   axis=1)
        
    return user_prod_reviewscore_data

def surprise_df(data):
    
    scale = (data.estimator.min(), data.estimator.max())
    reader = Reader(rating_scale=scale)

    # The columns must correspond to user id, item id and ratings (in that order).
    df = Dataset.load_from_df(data[['customer_unique_id','productId','estimator']], reader)
    
    return df

# %%
def final_model(data):
    user_product_df = create_user_ratings_df(data)
    user_ratings_matrix = surprise_df(user_product_df)
    
    train_set, test_set = train_test_split(user_ratings_matrix, test_size=0.1, random_state=19)
    
    params = {'n_factors': 10, 'n_epochs': 50, 'lr_all': 0.01, 'reg_all': 0.1} 
    svdpp = SVDpp(n_factors=params['n_factors'], 
                    n_epochs=params['n_epochs'],
                    lr_all=params['lr_all'], 
                    reg_all=params['reg_all'])
    svdpp.fit(train_set)
    predictions = svdpp.test(test_set)
    rmse = accuracy.rmse(predictions,verbose=False)
            
    return predictions, rmse, train_set
    
final_predictions, final_rmse, train_set = final_model(repeater_data)

# %%
repeater_data
# Out:
#         Unnamed: 0  Unnamed: 0.1 order_id  payment_sequential payment_type  \
# 9                9             9  ON56470                   1  credit_card
# 10              10            10  ON56470                   1  credit_card
# 14              14            14  ON34004                   1       boleto
# 37              37            37  ON25811                   1  credit_card
# 38              38            38  ON25811                   1  credit_card
# ...            ...           ...      ...                 ...          ...
# 100842      100842        100842  ON07748                   1  credit_card
# 100843      100843        100843  ON98785                   1  credit_card
# 100844      100844        100844  ON98785                   1  credit_card
# 100845      100845        100845  ON98785                   1  credit_card
# 100847      100847        100847  ON47795                   1  credit_card
#
#         payment_installments order_status order_purchase_timestamp  \
# 9                         10    delivered         11/28/2017 16:27
# 10                        10    delivered         11/28/2017 16:27
# 14                         1    delivered           8/4/2018 14:40
# 37                         1    delivered          7/27/2018 13:11
# 38                         1    delivered          7/27/2018 13:11
# ...                      ...          ...                      ...
# 100842                     3    delivered          1/31/2018 21:22
# 100843                     3    delivered           5/8/2018 21:04
# 100844                     3    delivered           5/8/2018 21:04
# 100845                     3    delivered           5/8/2018 21:04
# 100847                     6    delivered          4/20/2017 13:07
#
#        order_estimated_delivery_date  order_item_id  ... review_id  \
# 9                    12/18/2017 0:00              2  ...   PR80991
# 10                   12/18/2017 0:00              1  ...   PR80991
# 14                    8/10/2018 0:00              1  ...   PR08376
# 37                    8/15/2018 0:00              2  ...   PR59952
# 38                    8/15/2018 0:00              4  ...   PR59952
# ...                              ...            ...  ...       ...
# 100842                2/23/2018 0:00              2  ...   PR82775
# 100843                5/29/2018 0:00              1  ...   PR54011
# 100844                5/29/2018 0:00              2  ...   PR54011
# 100845                5/29/2018 0:00              3  ...   PR54011
# 100847                5/15/2017 0:00              1  ...   PR61174
#
#         review_score  review_comment_title  \
# 9                  5                   NaN
# 10                 5                   NaN
# 14                 4                   Bom
# 37                 5       super recomendo
# 38                 5       super recomendo
# ...              ...                   ...
# 100842             5                   NaN
# 100843             5                   NaN
# 100844             5                   NaN
# 100845             5                   NaN
# 100847             5                   NaN
#
#                                    review_comment_message  \
# 9       produto ótimo tudo muito bom só uma coisa eu n...
# 10      produto ótimo tudo muito bom só uma coisa eu n...
# 14                       Chegou atrasado mas está valendo
# 37                Produto exatamente conforme solicitação
# 38                Produto exatamente conforme solicitação
# ...                                                   ...
# 100842                                                NaN
# 100843                                                NaN
# 100844                                                NaN
# 100845                                                NaN
# 100847                                                NaN
#
#        review_creation_date review_answer_timestamp  total_payment  \
# 9           12/16/2017 0:00        12/18/2017 11:16         520.24
# 10          12/16/2017 0:00        12/18/2017 11:16         520.24
# 14           8/15/2018 0:00          8/17/2018 5:10         126.23
# 37            8/1/2018 0:00          8/3/2018 18:00        1037.44
# 38            8/1/2018 0:00          8/3/2018 18:00        1037.44
# ...                     ...                     ...            ...
# 100842       2/10/2018 0:00         2/12/2018 14:19         457.32
# 100843       5/22/2018 0:00         5/23/2018 22:43         358.02
# 100844       5/22/2018 0:00         5/23/2018 22:43         358.02
# 100845       5/22/2018 0:00         5/23/2018 22:43         358.02
# 100847        5/4/2017 0:00          5/5/2017 10:50          68.55
#
#                                              product_name  \
# 9                            Wheat Free Blueberry Muffins
# 10           Kellogg's Pop-Tarts Frosted S'mores Pastries
# 14                    100% Recycled 1-Ply Bathroom Tissue
# 37      Ultra Comfort Care 2-Ply Double Rolls Toilet P...
# 38                             Chorizo Hemp Soy-Free Tofu
# ...                                                   ...
# 100842                      Black Truffle Goat Cheese Log
# 100843                    Daily Moisture Quench Body Wash
# 100844                    Daily Moisture Quench Body Wash
# 100845                    Daily Moisture Quench Body Wash
# 100847                                        Bimini cap
#
#         product_category_new  repeater
# 9             Love with food         1
# 10            Love with food         1
# 14                  MunchPak         1
# 37           packaged cheese         1
# 38           packaged cheese         1
# ...                      ...       ...
# 100842          Hand Luggage         1
# 100843        chips pretzels         1
# 100844   energy granola bars         1
# 100845           paper goods         1
# 100847          frozen meals         1
#
# [31286 rows x 42 columns]

# %%
final_predictions
# Out:
# [Prediction(uid='C71088', iid='P10025', r_ui=5.0, est=4.326069869986271, details={'was_impossible': False}),
#  Prediction(uid='C88921', iid='P14134', r_ui=3.0, est=3.242377724301927, details={'was_impossible': False}),
#  Prediction(uid='C92824', iid='P28011', r_ui=5.0, est=4.455683698559296, details={'was_impossible': False}),
#  Prediction(uid='C31650', iid='P10696', r_ui=4.0, est=3.5235334909874108, details={'was_impossible': False}),
#  Prediction(uid='C61824', iid='P22999', r_ui=4.0, est=3.493849437299051, details={'was_impossible': False}),
#  Prediction(uid='C17405', iid='P06326', r_ui=1.0, est=2.5631269240294685, details={'was_impossible': False}),
#  Prediction(uid='C24131', iid='P08124', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C48244', iid='P25134', r_ui=5.0, est=3.6143862842914563, details={'was_impossible': False}),
#  Prediction(uid='C18928', iid='P22148', r_ui=5.0, est=4.28453202353728, details={'was_impossible': False}),
#  Prediction(uid='C61990', iid='P03753', r_ui=5.0, est=3.6410686031536854, details={'was_impossible': False}),
#  Prediction(uid='C52695', iid='P04830', r_ui=2.0, est=3.6966330824551, details={'was_impossible': False}),
#  Prediction(uid='C61284', iid='P30350', r_ui=5.0, est=3.117542434069315, details={'was_impossible': False}),
#  Prediction(uid='C16672', iid='P05201', r_ui=5.0, est=4.200802862902344, details={'was_impossible': False}),
#  Prediction(uid='C87054', iid='P18946', r_ui=5.0, est=3.2882447896486986, details={'was_impossible': False}),
#  Prediction(uid='C31682', iid='P31659', r_ui=5.0, est=4.18047041105594, details={'was_impossible': False}),
#  Prediction(uid='C81086', iid='P13319', r_ui=5.0, est=4.133682925122863, details={'was_impossible': False}),
#  Prediction(uid='C58216', iid='P22039', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C27612', iid='P04175', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C17043', iid='P07123', r_ui=5.0, est=4.08104139236967, details={'was_impossible': False}),
#  Prediction(uid='C07085', iid='P30212', r_ui=5.0, est=4.228259434659008, details={'was_impossible': False}),
#  Prediction(uid='C08197', iid='P02928', r_ui=5.0, est=4.299341377894789, details={'was_impossible': False}),
#  Prediction(uid='C63603', iid='P20627', r_ui=1.0, est=1.4728642355626969, details={'was_impossible': False}),
#  Prediction(uid='C08441', iid='P21867', r_ui=2.0, est=3.224633719300603, details={'was_impossible': False}),
#  Prediction(uid='C52439', iid='P06326', r_ui=5.0, est=4.222324101674647, details={'was_impossible': False}),
#  Prediction(uid='C85249', iid='P06715', r_ui=1.0, est=3.816797377769408, details={'was_impossible': False}),
#  Prediction(uid='C58834', iid='P16762', r_ui=5.0, est=4.03666401147669, details={'was_impossible': False}),
#  Prediction(uid='C60211', iid='P04830', r_ui=1.0, est=3.6966330824551, details={'was_impossible': False}),
#  Prediction(uid='C07405', iid='P03757', r_ui=4.0, est=4.1362572904794686, details={'was_impossible': False}),
#  Prediction(uid='C26871', iid='P10268', r_ui=3.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C70943', iid='P03185', r_ui=4.0, est=3.894547781647773, details={'was_impossible': False}),
#  Prediction(uid='C32350', iid='P09557', r_ui=1.0, est=2.044926490736122, details={'was_impossible': False}),
#  Prediction(uid='C59050', iid='P15444', r_ui=1.0, est=3.042066877537762, details={'was_impossible': False}),
#  Prediction(uid='C65043', iid='P32752', r_ui=1.0, est=2.1815579781801144, details={'was_impossible': False}),
#  Prediction(uid='C25946', iid='P31678', r_ui=5.0, est=4.091391878766128, details={'was_impossible': False}),
#  Prediction(uid='C33875', iid='P21701', r_ui=5.0, est=3.313633991263302, details={'was_impossible': False}),
#  Prediction(uid='C76360', iid='P06644', r_ui=5.0, est=2.9367254740453523, details={'was_impossible': False}),
#  Prediction(uid='C92666', iid='P30182', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C90909', iid='P17253', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C52025', iid='P20770', r_ui=5.0, est=4.061339070634541, details={'was_impossible': False}),
#  Prediction(uid='C63047', iid='P31011', r_ui=1.0, est=3.9045157567776863, details={'was_impossible': False}),
#  Prediction(uid='C57384', iid='P02589', r_ui=4.0, est=3.3084787777664464, details={'was_impossible': False}),
#  Prediction(uid='C40091', iid='P18222', r_ui=5.0, est=4.7104038356678, details={'was_impossible': False}),
#  Prediction(uid='C65010', iid='P15561', r_ui=5.0, est=3.9453799474436617, details={'was_impossible': False}),
#  Prediction(uid='C41564', iid='P32098', r_ui=1.0, est=2.843871795789805, details={'was_impossible': False}),
#  Prediction(uid='C96927', iid='P14408', r_ui=1.0, est=2.405070205102445, details={'was_impossible': False}),
#  Prediction(uid='C83983', iid='P19095', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C68548', iid='P18126', r_ui=5.0, est=3.474601655313473, details={'was_impossible': False}),
#  Prediction(uid='C84658', iid='P19872', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C48426', iid='P00633', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C16222', iid='P06339', r_ui=2.0, est=3.8835257357227597, details={'was_impossible': False}),
#  Prediction(uid='C38605', iid='P06758', r_ui=4.0, est=4.071724349120169, details={'was_impossible': False}),
#  Prediction(uid='C62186', iid='P30869', r_ui=5.0, est=4.421036480921184, details={'was_impossible': False}),
#  Prediction(uid='C26559', iid='P06326', r_ui=5.0, est=4.073550206948338, details={'was_impossible': False}),
#  Prediction(uid='C13348', iid='P04449', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C90613', iid='P12221', r_ui=5.0, est=3.005626044246703, details={'was_impossible': False}),
#  Prediction(uid='C38105', iid='P01674', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C75213', iid='P09122', r_ui=5.0, est=3.304914631834634, details={'was_impossible': False}),
#  Prediction(uid='C88713', iid='P17815', r_ui=5.0, est=4.144232378588067, details={'was_impossible': False}),
#  Prediction(uid='C32794', iid='P32346', r_ui=3.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C31174', iid='P26971', r_ui=5.0, est=4.105546018793054, details={'was_impossible': False}),
#  Prediction(uid='C64701', iid='P13085', r_ui=1.0, est=2.8984836879687665, details={'was_impossible': False}),
#  Prediction(uid='C39532', iid='P29761', r_ui=5.0, est=2.832446600099214, details={'was_impossible': False}),
#  Prediction(uid='C50533', iid='P18504', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C88182', iid='P06292', r_ui=4.0, est=3.652999140832602, details={'was_impossible': False}),
#  Prediction(uid='C43188', iid='P06072', r_ui=2.0, est=3.286054881343584, details={'was_impossible': False}),
#  Prediction(uid='C48530', iid='P19397', r_ui=2.0, est=4.1098173987808275, details={'was_impossible': False}),
#  Prediction(uid='C23975', iid='P07539', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C44668', iid='P21202', r_ui=1.0, est=1.4909736512098255, details={'was_impossible': False}),
#  Prediction(uid='C08208', iid='P16646', r_ui=2.0, est=3.735895047937914, details={'was_impossible': False}),
#  Prediction(uid='C17624', iid='P08217', r_ui=5.0, est=3.3331344808121384, details={'was_impossible': False}),
#  Prediction(uid='C33886', iid='P22656', r_ui=5.0, est=4.410289318132353, details={'was_impossible': False}),
#  Prediction(uid='C35879', iid='P02663', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C64142', iid='P03001', r_ui=4.0, est=3.8089040981400757, details={'was_impossible': False}),
#  Prediction(uid='C28183', iid='P20827', r_ui=4.0, est=3.8742427245692777, details={'was_impossible': False}),
#  Prediction(uid='C03714', iid='P12848', r_ui=5.0, est=4.121168983496321, details={'was_impossible': False}),
#  Prediction(uid='C45913', iid='P31350', r_ui=4.0, est=3.410122871183389, details={'was_impossible': False}),
#  Prediction(uid='C47147', iid='P05100', r_ui=3.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C72865', iid='P31160', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C31417', iid='P25707', r_ui=1.0, est=2.5488247150746597, details={'was_impossible': False}),
#  Prediction(uid='C55663', iid='P25930', r_ui=5.0, est=4.263172035429379, details={'was_impossible': False}),
#  Prediction(uid='C94484', iid='P14525', r_ui=5.0, est=4.260308675440929, details={'was_impossible': False}),
#  Prediction(uid='C10913', iid='P21100', r_ui=1.0, est=3.537148055998182, details={'was_impossible': False}),
#  Prediction(uid='C53649', iid='P14201', r_ui=1.0, est=2.989550277520622, details={'was_impossible': False}),
#  Prediction(uid='C20472', iid='P06208', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C05097', iid='P17230', r_ui=4.0, est=2.7989610220674406, details={'was_impossible': False}),
#  Prediction(uid='C49573', iid='P05869', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C96401', iid='P05450', r_ui=5.0, est=3.9697888460146014, details={'was_impossible': False}),
#  Prediction(uid='C56209', iid='P24025', r_ui=5.0, est=4.128242744204974, details={'was_impossible': False}),
#  Prediction(uid='C07020', iid='P02443', r_ui=5.0, est=3.948930745720644, details={'was_impossible': False}),
#  Prediction(uid='C08085', iid='P00612', r_ui=5.0, est=3.1405114971972097, details={'was_impossible': False}),
#  Prediction(uid='C52286', iid='P07721', r_ui=1.0, est=3.0750402380410375, details={'was_impossible': False}),
#  Prediction(uid='C17738', iid='P02854', r_ui=5.0, est=2.9773270326342844, details={'was_impossible': False}),
#  Prediction(uid='C96511', iid='P01187', r_ui=5.0, est=4.04242688092019, details={'was_impossible': False}),
#  Prediction(uid='C13906', iid='P22083', r_ui=5.0, est=3.643618635129116, details={'was_impossible': False}),
#  Prediction(uid='C82481', iid='P09940', r_ui=1.0, est=2.682361062604538, details={'was_impossible': False}),
#  Prediction(uid='C04508', iid='P15847', r_ui=1.0, est=4.131273660640274, details={'was_impossible': False}),
#  Prediction(uid='C00755', iid='P03185', r_ui=3.0, est=3.1625616810178934, details={'was_impossible': False}),
#  Prediction(uid='C09325', iid='P04014', r_ui=1.0, est=2.8862393713019165, details={'was_impossible': False}),
#  Prediction(uid='C61238', iid='P25745', r_ui=5.0, est=3.828509109061457, details={'was_impossible': False}),
#  Prediction(uid='C23611', iid='P00634', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C05433', iid='P30661', r_ui=3.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C85948', iid='P25818', r_ui=3.0, est=3.517484903398513, details={'was_impossible': False}),
#  Prediction(uid='C24303', iid='P02596', r_ui=3.0, est=4.434778106511497, details={'was_impossible': False}),
#  Prediction(uid='C67886', iid='P06963', r_ui=1.0, est=4.064867455411939, details={'was_impossible': False}),
#  Prediction(uid='C09896', iid='P25403', r_ui=1.0, est=2.1204887829827075, details={'was_impossible': False}),
#  Prediction(uid='C27185', iid='P13303', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C11492', iid='P20696', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C56293', iid='P29348', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C64836', iid='P15871', r_ui=1.0, est=2.987315092587501, details={'was_impossible': False}),
#  Prediction(uid='C06170', iid='P19134', r_ui=1.0, est=2.93613482082464, details={'was_impossible': False}),
#  Prediction(uid='C43360', iid='P16725', r_ui=5.0, est=4.054970927881278, details={'was_impossible': False}),
#  Prediction(uid='C78496', iid='P19016', r_ui=1.0, est=3.894307520459098, details={'was_impossible': False}),
#  Prediction(uid='C56041', iid='P25842', r_ui=5.0, est=3.8877155690743357, details={'was_impossible': False}),
#  Prediction(uid='C50387', iid='P27793', r_ui=5.0, est=4.041978410532316, details={'was_impossible': False}),
#  Prediction(uid='C79869', iid='P26998', r_ui=5.0, est=3.986702905318371, details={'was_impossible': False}),
#  Prediction(uid='C09781', iid='P26928', r_ui=5.0, est=2.927147987017732, details={'was_impossible': False}),
#  Prediction(uid='C93247', iid='P09461', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C43030', iid='P19035', r_ui=5.0, est=4.110810015372593, details={'was_impossible': False}),
#  Prediction(uid='C11301', iid='P18793', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C10340', iid='P30780', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C86919', iid='P31290', r_ui=5.0, est=4.0888432178402665, details={'was_impossible': False}),
#  Prediction(uid='C41452', iid='P12806', r_ui=5.0, est=2.785917651404713, details={'was_impossible': False}),
#  Prediction(uid='C11250', iid='P12741', r_ui=4.0, est=3.9029095654002797, details={'was_impossible': False}),
#  Prediction(uid='C29290', iid='P07272', r_ui=1.0, est=4.042651317228455, details={'was_impossible': False}),
#  Prediction(uid='C49751', iid='P31930', r_ui=2.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C62257', iid='P26194', r_ui=5.0, est=3.0711857327922765, details={'was_impossible': False}),
#  Prediction(uid='C12555', iid='P12927', r_ui=5.0, est=3.732513877646447, details={'was_impossible': False}),
#  Prediction(uid='C17186', iid='P27188', r_ui=5.0, est=4.159942223864237, details={'was_impossible': False}),
#  Prediction(uid='C70963', iid='P04501', r_ui=4.0, est=3.732581410401854, details={'was_impossible': False}),
#  Prediction(uid='C84801', iid='P27907', r_ui=5.0, est=4.016071525551898, details={'was_impossible': False}),
#  Prediction(uid='C12551', iid='P25649', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C83339', iid='P12101', r_ui=5.0, est=3.7031609900885685, details={'was_impossible': False}),
#  Prediction(uid='C29478', iid='P02855', r_ui=5.0, est=4.315968107739519, details={'was_impossible': False}),
#  Prediction(uid='C34569', iid='P18865', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C96036', iid='P14988', r_ui=5.0, est=3.2958996154947657, details={'was_impossible': False}),
#  Prediction(uid='C34792', iid='P24849', r_ui=1.0, est=3.0262583056742764, details={'was_impossible': False}),
#  Prediction(uid='C89711', iid='P14737', r_ui=1.0, est=2.8411603426855203, details={'was_impossible': False}),
#  Prediction(uid='C63229', iid='P24607', r_ui=1.0, est=3.337572899921414, details={'was_impossible': False}),
#  Prediction(uid='C69635', iid='P14582', r_ui=5.0, est=4.175751332397185, details={'was_impossible': False}),
#  Prediction(uid='C36274', iid='P09790', r_ui=1.0, est=2.9380697680893753, details={'was_impossible': False}),
#  Prediction(uid='C75033', iid='P06326', r_ui=4.0, est=3.852038962140227, details={'was_impossible': False}),
#  Prediction(uid='C45624', iid='P09412', r_ui=2.0, est=3.227000262607352, details={'was_impossible': False}),
#  Prediction(uid='C53552', iid='P02603', r_ui=1.0, est=2.9208990867324247, details={'was_impossible': False}),
#  Prediction(uid='C17597', iid='P23817', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C61574', iid='P22076', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C16249', iid='P14948', r_ui=4.0, est=3.7500456934179223, details={'was_impossible': False}),
#  Prediction(uid='C63978', iid='P28047', r_ui=4.0, est=4.347631818982451, details={'was_impossible': False}),
#  Prediction(uid='C18095', iid='P27001', r_ui=3.0, est=4.093173597454138, details={'was_impossible': False}),
#  Prediction(uid='C44079', iid='P20250', r_ui=5.0, est=3.26230839025574, details={'was_impossible': False}),
#  Prediction(uid='C72406', iid='P23731', r_ui=5.0, est=3.520395365714329, details={'was_impossible': False}),
#  Prediction(uid='C57157', iid='P10388', r_ui=3.0, est=4.073431077286499, details={'was_impossible': False}),
#  Prediction(uid='C51785', iid='P21479', r_ui=5.0, est=4.129444430239272, details={'was_impossible': False}),
#  Prediction(uid='C40761', iid='P14875', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C61106', iid='P03749', r_ui=5.0, est=3.3679311738441315, details={'was_impossible': False}),
#  Prediction(uid='C07277', iid='P28011', r_ui=4.0, est=3.980652350049979, details={'was_impossible': False}),
#  Prediction(uid='C40392', iid='P03185', r_ui=1.0, est=3.676694148671711, details={'was_impossible': False}),
#  Prediction(uid='C87753', iid='P17230', r_ui=1.0, est=2.9076811060825998, details={'was_impossible': False}),
#  Prediction(uid='C67814', iid='P32681', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C90913', iid='P32198', r_ui=3.0, est=3.5915743377630944, details={'was_impossible': False}),
#  Prediction(uid='C07112', iid='P28097', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C60855', iid='P16980', r_ui=5.0, est=4.436910184440553, details={'was_impossible': False}),
#  Prediction(uid='C18548', iid='P21197', r_ui=5.0, est=4.189675799668464, details={'was_impossible': False}),
#  Prediction(uid='C72760', iid='P21189', r_ui=5.0, est=4.767544929681112, details={'was_impossible': False}),
#  Prediction(uid='C61106', iid='P22498', r_ui=1.0, est=2.5104761444677406, details={'was_impossible': False}),
#  Prediction(uid='C44275', iid='P03185', r_ui=1.0, est=2.855545453380968, details={'was_impossible': False}),
#  Prediction(uid='C70609', iid='P16501', r_ui=1.0, est=2.932879678355617, details={'was_impossible': False}),
#  Prediction(uid='C42746', iid='P25462', r_ui=5.0, est=4.488191711327091, details={'was_impossible': False}),
#  Prediction(uid='C15334', iid='P15401', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C18453', iid='P11463', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C12270', iid='P29155', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C17922', iid='P30940', r_ui=5.0, est=3.952310033666083, details={'was_impossible': False}),
#  Prediction(uid='C89904', iid='P11640', r_ui=5.0, est=4.2597202894158235, details={'was_impossible': False}),
#  Prediction(uid='C73415', iid='P25685', r_ui=1.0, est=2.977976437058138, details={'was_impossible': False}),
#  Prediction(uid='C34669', iid='P30830', r_ui=5.0, est=4.106300397555847, details={'was_impossible': False}),
#  Prediction(uid='C69392', iid='P19886', r_ui=5.0, est=4.1143688157291605, details={'was_impossible': False}),
#  Prediction(uid='C59232', iid='P16646', r_ui=1.0, est=3.735895047937914, details={'was_impossible': False}),
#  Prediction(uid='C54047', iid='P07078', r_ui=4.0, est=3.8200067201203183, details={'was_impossible': False}),
#  Prediction(uid='C73512', iid='P21682', r_ui=5.0, est=4.078500925143183, details={'was_impossible': False}),
#  Prediction(uid='C04718', iid='P04159', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C40257', iid='P05548', r_ui=5.0, est=4.430598811102097, details={'was_impossible': False}),
#  Prediction(uid='C15211', iid='P29377', r_ui=5.0, est=3.540462376030602, details={'was_impossible': False}),
#  Prediction(uid='C14547', iid='P12927', r_ui=5.0, est=4.088867532583573, details={'was_impossible': False}),
#  Prediction(uid='C46514', iid='P32260', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C46409', iid='P03461', r_ui=4.0, est=3.8113182991578167, details={'was_impossible': False}),
#  Prediction(uid='C55813', iid='P09940', r_ui=5.0, est=4.131050081908139, details={'was_impossible': False}),
#  Prediction(uid='C40402', iid='P13659', r_ui=5.0, est=4.085584377196495, details={'was_impossible': False}),
#  Prediction(uid='C57947', iid='P31065', r_ui=5.0, est=3.7360871019408792, details={'was_impossible': False}),
#  Prediction(uid='C53568', iid='P09975', r_ui=3.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C72098', iid='P14111', r_ui=5.0, est=4.6775170573867, details={'was_impossible': False}),
#  Prediction(uid='C58126', iid='P03185', r_ui=5.0, est=3.4399540974695824, details={'was_impossible': False}),
#  Prediction(uid='C40197', iid='P26236', r_ui=4.0, est=4.090590216886648, details={'was_impossible': False}),
#  Prediction(uid='C40435', iid='P00405', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C32908', iid='P05913', r_ui=5.0, est=3.9953243974179387, details={'was_impossible': False}),
#  Prediction(uid='C36399', iid='P22402', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C43942', iid='P20697', r_ui=5.0, est=4.814209368772825, details={'was_impossible': False}),
#  Prediction(uid='C23215', iid='P29124', r_ui=3.0, est=3.4074957927648466, details={'was_impossible': False}),
#  Prediction(uid='C52165', iid='P27399', r_ui=4.0, est=4.444396593023828, details={'was_impossible': False}),
#  Prediction(uid='C83912', iid='P14017', r_ui=4.0, est=3.647075707380308, details={'was_impossible': False}),
#  Prediction(uid='C05702', iid='P04815', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C63243', iid='P31470', r_ui=5.0, est=4.089774535766079, details={'was_impossible': False}),
#  Prediction(uid='C84486', iid='P11033', r_ui=5.0, est=4.709089218181718, details={'was_impossible': False}),
#  Prediction(uid='C35915', iid='P09041', r_ui=2.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C92798', iid='P31283', r_ui=5.0, est=4.665463050104095, details={'was_impossible': False}),
#  Prediction(uid='C25636', iid='P13463', r_ui=5.0, est=3.2503345853226513, details={'was_impossible': False}),
#  Prediction(uid='C18988', iid='P23398', r_ui=5.0, est=3.239664804636358, details={'was_impossible': False}),
#  Prediction(uid='C56217', iid='P18768', r_ui=2.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C46189', iid='P15983', r_ui=1.0, est=3.9270990349854484, details={'was_impossible': False}),
#  Prediction(uid='C90298', iid='P28440', r_ui=4.0, est=3.845773860474723, details={'was_impossible': False}),
#  Prediction(uid='C54729', iid='P02375', r_ui=5.0, est=4.0149412029091875, details={'was_impossible': False}),
#  Prediction(uid='C11250', iid='P06515', r_ui=4.0, est=3.8083075046830634, details={'was_impossible': False}),
#  Prediction(uid='C17129', iid='P25403', r_ui=5.0, est=4.4084660767256105, details={'was_impossible': False}),
#  Prediction(uid='C50640', iid='P08213', r_ui=5.0, est=4.135139534887884, details={'was_impossible': False}),
#  Prediction(uid='C56070', iid='P07935', r_ui=1.0, est=3.4209550698427056, details={'was_impossible': False}),
#  Prediction(uid='C53404', iid='P32509', r_ui=2.0, est=3.2585464524177183, details={'was_impossible': False}),
#  Prediction(uid='C26247', iid='P21837', r_ui=4.0, est=3.5601590067446085, details={'was_impossible': False}),
#  Prediction(uid='C19680', iid='P16666', r_ui=2.0, est=2.9397525539139706, details={'was_impossible': False}),
#  Prediction(uid='C32839', iid='P13514', r_ui=4.0, est=4.093860736960296, details={'was_impossible': False}),
#  Prediction(uid='C30378', iid='P32166', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C09200', iid='P18367', r_ui=4.0, est=4.205769207733282, details={'was_impossible': False}),
#  Prediction(uid='C04730', iid='P00593', r_ui=1.0, est=4.108965962352128, details={'was_impossible': False}),
#  Prediction(uid='C21075', iid='P04478', r_ui=1.0, est=4.117063439151149, details={'was_impossible': False}),
#  Prediction(uid='C08282', iid='P12136', r_ui=5.0, est=4.149690996555612, details={'was_impossible': False}),
#  Prediction(uid='C67004', iid='P32673', r_ui=4.0, est=3.7616752155685065, details={'was_impossible': False}),
#  Prediction(uid='C67696', iid='P25403', r_ui=1.0, est=3.620110632296644, details={'was_impossible': False}),
#  Prediction(uid='C73249', iid='P21837', r_ui=4.0, est=3.5601590067446085, details={'was_impossible': False}),
#  Prediction(uid='C52799', iid='P17412', r_ui=5.0, est=4.398416796850701, details={'was_impossible': False}),
#  Prediction(uid='C28505', iid='P25485', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C00182', iid='P29511', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C64449', iid='P12850', r_ui=1.0, est=3.1519133921495714, details={'was_impossible': False}),
#  Prediction(uid='C79035', iid='P19401', r_ui=4.0, est=4.503362635356484, details={'was_impossible': False}),
#  Prediction(uid='C36667', iid='P31762', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C67058', iid='P22938', r_ui=5.0, est=3.83737466995126, details={'was_impossible': False}),
#  Prediction(uid='C20235', iid='P06328', r_ui=4.0, est=4.009677541981366, details={'was_impossible': False}),
#  Prediction(uid='C55454', iid='P30281', r_ui=3.0, est=2.7542416983557296, details={'was_impossible': False}),
#  Prediction(uid='C28437', iid='P07956', r_ui=4.0, est=4.058547089601788, details={'was_impossible': False}),
#  Prediction(uid='C35986', iid='P00313', r_ui=5.0, est=3.4408868341658407, details={'was_impossible': False}),
#  Prediction(uid='C67020', iid='P30270', r_ui=5.0, est=4.05668524060112, details={'was_impossible': False}),
#  Prediction(uid='C89303', iid='P21197', r_ui=5.0, est=4.782180953600206, details={'was_impossible': False}),
#  Prediction(uid='C67257', iid='P22092', r_ui=1.0, est=2.419143304792826, details={'was_impossible': False}),
#  Prediction(uid='C12502', iid='P05190', r_ui=3.0, est=4.197131656345508, details={'was_impossible': False}),
#  Prediction(uid='C84308', iid='P01678', r_ui=3.5, est=3.461227216972374, details={'was_impossible': False}),
#  Prediction(uid='C56417', iid='P21881', r_ui=1.0, est=1.3679867946237254, details={'was_impossible': False}),
#  Prediction(uid='C53078', iid='P07068', r_ui=5.0, est=3.482778998944276, details={'was_impossible': False}),
#  Prediction(uid='C59842', iid='P03232', r_ui=3.0, est=3.165385347094888, details={'was_impossible': False}),
#  Prediction(uid='C55237', iid='P12465', r_ui=5.0, est=2.9730194192166777, details={'was_impossible': False}),
#  Prediction(uid='C93219', iid='P29602', r_ui=5.0, est=4.195251371356502, details={'was_impossible': False}),
#  Prediction(uid='C47089', iid='P25956', r_ui=5.0, est=4.434038820836694, details={'was_impossible': False}),
#  Prediction(uid='C51892', iid='P02321', r_ui=5.0, est=4.2293173625393194, details={'was_impossible': False}),
#  Prediction(uid='C83700', iid='P18079', r_ui=5.0, est=4.2294614452391635, details={'was_impossible': False}),
#  Prediction(uid='C87981', iid='P12712', r_ui=5.0, est=4.156443702539556, details={'was_impossible': False}),
#  Prediction(uid='C18710', iid='P04830', r_ui=1.0, est=3.6966330824551, details={'was_impossible': False}),
#  Prediction(uid='C47002', iid='P19935', r_ui=4.0, est=3.8961901995437227, details={'was_impossible': False}),
#  Prediction(uid='C20623', iid='P22962', r_ui=5.0, est=4.115939589791606, details={'was_impossible': False}),
#  Prediction(uid='C67157', iid='P03185', r_ui=4.0, est=3.676694148671711, details={'was_impossible': False}),
#  Prediction(uid='C67973', iid='P11283', r_ui=5.0, est=4.2373186543532375, details={'was_impossible': False}),
#  Prediction(uid='C29879', iid='P14479', r_ui=5.0, est=3.825994550328703, details={'was_impossible': False}),
#  Prediction(uid='C36871', iid='P20875', r_ui=5.0, est=4.2984932427989335, details={'was_impossible': False}),
#  Prediction(uid='C42861', iid='P19818', r_ui=5.0, est=4.584624678914734, details={'was_impossible': False}),
#  Prediction(uid='C47331', iid='P19417', r_ui=4.0, est=3.862600122167223, details={'was_impossible': False}),
#  Prediction(uid='C85448', iid='P22461', r_ui=1.0, est=4.172144735874915, details={'was_impossible': False}),
#  Prediction(uid='C55228', iid='P04296', r_ui=5.0, est=4.059814044195904, details={'was_impossible': False}),
#  Prediction(uid='C63221', iid='P17013', r_ui=5.0, est=4.2949035084119025, details={'was_impossible': False}),
#  Prediction(uid='C45532', iid='P12927', r_ui=3.0, est=3.732513877646447, details={'was_impossible': False}),
#  Prediction(uid='C54673', iid='P17767', r_ui=5.0, est=3.588585212996466, details={'was_impossible': False}),
#  Prediction(uid='C60167', iid='P29602', r_ui=5.0, est=4.195251371356502, details={'was_impossible': False}),
#  Prediction(uid='C64489', iid='P25141', r_ui=5.0, est=3.807302815888215, details={'was_impossible': False}),
#  Prediction(uid='C30438', iid='P04657', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C82342', iid='P11097', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C96084', iid='P20508', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C25310', iid='P02069', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C38163', iid='P18707', r_ui=4.0, est=4.53899960052138, details={'was_impossible': False}),
#  Prediction(uid='C63753', iid='P23774', r_ui=5.0, est=4.115672345313644, details={'was_impossible': False}),
#  Prediction(uid='C55409', iid='P13993', r_ui=1.0, est=2.9232077240473884, details={'was_impossible': False}),
#  Prediction(uid='C16322', iid='P21524', r_ui=2.0, est=3.836048281304175, details={'was_impossible': False}),
#  Prediction(uid='C75087', iid='P25086', r_ui=1.0, est=2.7221818286213515, details={'was_impossible': False}),
#  Prediction(uid='C51784', iid='P10659', r_ui=5.0, est=3.999378599574792, details={'was_impossible': False}),
#  Prediction(uid='C53929', iid='P25745', r_ui=5.0, est=3.828509109061457, details={'was_impossible': False}),
#  Prediction(uid='C33898', iid='P29711', r_ui=5.0, est=4.109089424428842, details={'was_impossible': False}),
#  Prediction(uid='C96687', iid='P29652', r_ui=1.0, est=2.482955061044457, details={'was_impossible': False}),
#  Prediction(uid='C66967', iid='P32443', r_ui=1.0, est=3.3992086901287966, details={'was_impossible': False}),
#  Prediction(uid='C88711', iid='P28306', r_ui=5.0, est=3.01898878691076, details={'was_impossible': False}),
#  Prediction(uid='C87134', iid='P03966', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C01526', iid='P08930', r_ui=2.0, est=2.6841371735692414, details={'was_impossible': False}),
#  Prediction(uid='C54934', iid='P26390', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C26004', iid='P20414', r_ui=5.0, est=4.322766636177825, details={'was_impossible': False}),
#  Prediction(uid='C67811', iid='P05354', r_ui=5.0, est=4.520882047931972, details={'was_impossible': False}),
#  Prediction(uid='C70892', iid='P16646', r_ui=5.0, est=3.735895047937914, details={'was_impossible': False}),
#  Prediction(uid='C66531', iid='P00595', r_ui=5.0, est=4.105446993454975, details={'was_impossible': False}),
#  Prediction(uid='C15674', iid='P25724', r_ui=5.0, est=4.758803757526476, details={'was_impossible': False}),
#  Prediction(uid='C51421', iid='P25403', r_ui=3.0, est=4.5077817069351225, details={'was_impossible': False}),
#  Prediction(uid='C17853', iid='P30067', r_ui=1.0, est=3.045268989373316, details={'was_impossible': False}),
#  Prediction(uid='C07542', iid='P12718', r_ui=3.6666666666666665, est=3.4906323510380126, details={'was_impossible': False}),
#  Prediction(uid='C19174', iid='P02816', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C95410', iid='P05842', r_ui=1.0, est=2.5501151973705802, details={'was_impossible': False}),
#  Prediction(uid='C57439', iid='P27536', r_ui=4.0, est=3.0956757491997475, details={'was_impossible': False}),
#  Prediction(uid='C14764', iid='P30773', r_ui=5.0, est=3.350455305202085, details={'was_impossible': False}),
#  Prediction(uid='C55718', iid='P25131', r_ui=5.0, est=3.8012273057958255, details={'was_impossible': False}),
#  Prediction(uid='C89087', iid='P06715', r_ui=2.0, est=4.343742052580381, details={'was_impossible': False}),
#  Prediction(uid='C65963', iid='P24986', r_ui=3.0, est=3.718262635232572, details={'was_impossible': False}),
#  Prediction(uid='C01498', iid='P10231', r_ui=4.0, est=4.262445017962735, details={'was_impossible': False}),
#  Prediction(uid='C59169', iid='P26285', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C40896', iid='P10785', r_ui=1.0, est=2.7051805253908237, details={'was_impossible': False}),
#  Prediction(uid='C49448', iid='P31485', r_ui=2.0, est=3.538474506392773, details={'was_impossible': False}),
#  Prediction(uid='C53405', iid='P11536', r_ui=2.0, est=3.268595715560234, details={'was_impossible': False}),
#  Prediction(uid='C01470', iid='P22549', r_ui=5.0, est=3.817200111370666, details={'was_impossible': False}),
#  Prediction(uid='C76950', iid='P09504', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C29705', iid='P23826', r_ui=5.0, est=3.2836251935486453, details={'was_impossible': False}),
#  Prediction(uid='C04233', iid='P32160', r_ui=5.0, est=4.115805594465813, details={'was_impossible': False}),
#  Prediction(uid='C43313', iid='P08907', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C80580', iid='P04623', r_ui=5.0, est=2.3567811214683565, details={'was_impossible': False}),
#  Prediction(uid='C65116', iid='P18224', r_ui=3.0, est=4.3400106089573445, details={'was_impossible': False}),
#  Prediction(uid='C10437', iid='P29890', r_ui=2.0, est=4.09918951913733, details={'was_impossible': False}),
#  Prediction(uid='C40995', iid='P03498', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C41298', iid='P16335', r_ui=5.0, est=4.582065524315816, details={'was_impossible': False}),
#  Prediction(uid='C25033', iid='P09234', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C25829', iid='P07833', r_ui=5.0, est=3.4811712622242106, details={'was_impossible': False}),
#  Prediction(uid='C95847', iid='P19481', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C87530', iid='P26785', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C47693', iid='P04398', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C76048', iid='P20634', r_ui=3.0, est=3.4448066004928375, details={'was_impossible': False}),
#  Prediction(uid='C83835', iid='P04558', r_ui=4.0, est=4.125726286979764, details={'was_impossible': False}),
#  Prediction(uid='C79022', iid='P04830', r_ui=2.0, est=3.6966330824551, details={'was_impossible': False}),
#  Prediction(uid='C51540', iid='P31987', r_ui=3.0, est=3.869037824825249, details={'was_impossible': False}),
#  Prediction(uid='C80493', iid='P28752', r_ui=5.0, est=3.4489183677253146, details={'was_impossible': False}),
#  Prediction(uid='C16829', iid='P15664', r_ui=5.0, est=4.227203893463454, details={'was_impossible': False}),
#  Prediction(uid='C05038', iid='P20615', r_ui=1.0, est=3.649517565972449, details={'was_impossible': False}),
#  Prediction(uid='C87872', iid='P12971', r_ui=3.0, est=3.99352954136206, details={'was_impossible': False}),
#  Prediction(uid='C59318', iid='P15541', r_ui=5.0, est=4.176168589080522, details={'was_impossible': False}),
#  Prediction(uid='C39109', iid='P10091', r_ui=3.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C23758', iid='P31106', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C15664', iid='P11101', r_ui=5.0, est=3.6752697137476105, details={'was_impossible': False}),
#  Prediction(uid='C76683', iid='P08811', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C91398', iid='P10749', r_ui=5.0, est=4.116582589036098, details={'was_impossible': False}),
#  Prediction(uid='C75918', iid='P05455', r_ui=5.0, est=3.4376594502428275, details={'was_impossible': False}),
#  Prediction(uid='C39313', iid='P09265', r_ui=1.0, est=4.082831508050208, details={'was_impossible': False}),
#  Prediction(uid='C87194', iid='P32193', r_ui=5.0, est=4.262180655801761, details={'was_impossible': False}),
#  Prediction(uid='C22264', iid='P28339', r_ui=2.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C86977', iid='P32321', r_ui=5.0, est=3.539230212038783, details={'was_impossible': False}),
#  Prediction(uid='C15864', iid='P16139', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C17632', iid='P10180', r_ui=4.0, est=3.712609100949122, details={'was_impossible': False}),
#  Prediction(uid='C09554', iid='P18143', r_ui=1.0, est=3.0881928226109663, details={'was_impossible': False}),
#  Prediction(uid='C50182', iid='P27066', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C55473', iid='P23815', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C96645', iid='P18445', r_ui=5.0, est=4.0451493707761665, details={'was_impossible': False}),
#  Prediction(uid='C70368', iid='P19465', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C75386', iid='P14538', r_ui=4.0, est=3.815290090877796, details={'was_impossible': False}),
#  Prediction(uid='C36667', iid='P25034', r_ui=5.0, est=3.5964308845384996, details={'was_impossible': False}),
#  Prediction(uid='C05765', iid='P32704', r_ui=4.0, est=3.9428541572902525, details={'was_impossible': False}),
#  Prediction(uid='C55805', iid='P10799', r_ui=1.0, est=3.775367912325699, details={'was_impossible': False}),
#  Prediction(uid='C81795', iid='P30281', r_ui=3.0, est=4.0441486381436835, details={'was_impossible': False}),
#  Prediction(uid='C44508', iid='P20367', r_ui=5.0, est=4.6815812150603895, details={'was_impossible': False}),
#  Prediction(uid='C68352', iid='P04290', r_ui=2.0, est=2.5282334861118283, details={'was_impossible': False}),
#  Prediction(uid='C95916', iid='P06134', r_ui=1.0, est=3.4195368058274185, details={'was_impossible': False}),
#  Prediction(uid='C77441', iid='P17444', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C54849', iid='P19967', r_ui=5.0, est=3.2595476868065774, details={'was_impossible': False}),
#  Prediction(uid='C88854', iid='P04846', r_ui=3.0, est=4.144069107352425, details={'was_impossible': False}),
#  Prediction(uid='C29205', iid='P27076', r_ui=5.0, est=3.8654883098686286, details={'was_impossible': False}),
#  Prediction(uid='C90165', iid='P10090', r_ui=3.0, est=3.9438006054349914, details={'was_impossible': False}),
#  Prediction(uid='C76018', iid='P23855', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C67302', iid='P23462', r_ui=5.0, est=4.532485328306912, details={'was_impossible': False}),
#  Prediction(uid='C20261', iid='P11705', r_ui=4.0, est=3.803003247649761, details={'was_impossible': False}),
#  Prediction(uid='C64613', iid='P01147', r_ui=5.0, est=3.7583496260609457, details={'was_impossible': False}),
#  Prediction(uid='C44782', iid='P03185', r_ui=5.0, est=3.549547874428578, details={'was_impossible': False}),
#  Prediction(uid='C16099', iid='P27289', r_ui=5.0, est=3.659775633766544, details={'was_impossible': False}),
#  Prediction(uid='C68802', iid='P04235', r_ui=1.0, est=4.039761442323893, details={'was_impossible': False}),
#  Prediction(uid='C63013', iid='P00922', r_ui=3.0, est=3.8018782962795252, details={'was_impossible': False}),
#  Prediction(uid='C91032', iid='P12312', r_ui=3.0, est=3.855569208096143, details={'was_impossible': False}),
#  Prediction(uid='C92003', iid='P01798', r_ui=5.0, est=4.685663814436823, details={'was_impossible': False}),
#  Prediction(uid='C72168', iid='P32632', r_ui=2.0, est=3.136891021175413, details={'was_impossible': False}),
#  Prediction(uid='C04838', iid='P27484', r_ui=5.0, est=4.1135392391403975, details={'was_impossible': False}),
#  Prediction(uid='C45753', iid='P23462', r_ui=5.0, est=4.564290067007569, details={'was_impossible': False}),
#  Prediction(uid='C81639', iid='P05435', r_ui=3.0, est=2.927653762918153, details={'was_impossible': False}),
#  Prediction(uid='C86387', iid='P30491', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C33670', iid='P25508', r_ui=5.0, est=4.0806766490341, details={'was_impossible': False}),
#  Prediction(uid='C25767', iid='P09696', r_ui=4.0, est=3.826639105097695, details={'was_impossible': False}),
#  Prediction(uid='C71015', iid='P31474', r_ui=1.0, est=2.694758324546297, details={'was_impossible': False}),
#  Prediction(uid='C95484', iid='P06479', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C07660', iid='P18273', r_ui=5.0, est=4.253259119170433, details={'was_impossible': False}),
#  Prediction(uid='C46549', iid='P30783', r_ui=4.0, est=4.212491334244138, details={'was_impossible': False}),
#  Prediction(uid='C28792', iid='P26597', r_ui=5.0, est=3.271722398727109, details={'was_impossible': False}),
#  Prediction(uid='C56568', iid='P06598', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C90516', iid='P12187', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C87975', iid='P25403', r_ui=1.0, est=1.8893534009072204, details={'was_impossible': False}),
#  Prediction(uid='C78631', iid='P03185', r_ui=5.0, est=4.729045159717844, details={'was_impossible': False}),
#  Prediction(uid='C40524', iid='P09382', r_ui=4.0, est=3.8258503403320496, details={'was_impossible': False}),
#  Prediction(uid='C36289', iid='P17134', r_ui=2.0, est=3.6562017841024903, details={'was_impossible': False}),
#  Prediction(uid='C39332', iid='P28011', r_ui=5.0, est=4.230504310268086, details={'was_impossible': False}),
#  Prediction(uid='C92818', iid='P32539', r_ui=5.0, est=4.1210374393550655, details={'was_impossible': False}),
#  Prediction(uid='C32938', iid='P09777', r_ui=5.0, est=3.980379710218042, details={'was_impossible': False}),
#  Prediction(uid='C84658', iid='P31520', r_ui=5.0, est=3.613514002645844, details={'was_impossible': False}),
#  Prediction(uid='C54978', iid='P15862', r_ui=1.0, est=2.9415074055669717, details={'was_impossible': False}),
#  Prediction(uid='C80902', iid='P31436', r_ui=5.0, est=4.108554304524459, details={'was_impossible': False}),
#  Prediction(uid='C80969', iid='P24897', r_ui=4.0, est=4.295884070475339, details={'was_impossible': False}),
#  Prediction(uid='C83781', iid='P05190', r_ui=3.0, est=3.965065004443739, details={'was_impossible': False}),
#  Prediction(uid='C43693', iid='P05816', r_ui=5.0, est=3.398284256024898, details={'was_impossible': False}),
#  Prediction(uid='C13279', iid='P30061', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C17780', iid='P20124', r_ui=1.0, est=3.1301906455596633, details={'was_impossible': False}),
#  Prediction(uid='C85847', iid='P20528', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C40402', iid='P28873', r_ui=5.0, est=4.085584377196495, details={'was_impossible': False}),
#  Prediction(uid='C80055', iid='P28488', r_ui=2.0, est=2.91322593250968, details={'was_impossible': False}),
#  Prediction(uid='C48427', iid='P08218', r_ui=4.0, est=3.8297698020415183, details={'was_impossible': False}),
#  Prediction(uid='C46504', iid='P13271', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C39046', iid='P15993', r_ui=3.0, est=3.9551170742049737, details={'was_impossible': False}),
#  Prediction(uid='C07906', iid='P00950', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C55240', iid='P14960', r_ui=5.0, est=3.9398870363815526, details={'was_impossible': False}),
#  Prediction(uid='C29819', iid='P28488', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C02695', iid='P03548', r_ui=4.0, est=4.20911887374975, details={'was_impossible': False}),
#  Prediction(uid='C28958', iid='P10834', r_ui=5.0, est=4.274279716890563, details={'was_impossible': False}),
#  Prediction(uid='C42581', iid='P23408', r_ui=5.0, est=3.551158777499933, details={'was_impossible': False}),
#  Prediction(uid='C81907', iid='P09232', r_ui=5.0, est=4.1282692024843435, details={'was_impossible': False}),
#  Prediction(uid='C21673', iid='P07783', r_ui=1.0, est=4.094993877597842, details={'was_impossible': False}),
#  Prediction(uid='C33295', iid='P26088', r_ui=3.0, est=2.940698389140556, details={'was_impossible': False}),
#  Prediction(uid='C87885', iid='P01544', r_ui=1.0, est=4.063670065428576, details={'was_impossible': False}),
#  Prediction(uid='C31323', iid='P16393', r_ui=2.0, est=4.108093367658172, details={'was_impossible': False}),
#  Prediction(uid='C74998', iid='P01275', r_ui=2.0, est=3.259490589416941, details={'was_impossible': False}),
#  Prediction(uid='C11580', iid='P01099', r_ui=5.0, est=3.8344774357217264, details={'was_impossible': False}),
#  Prediction(uid='C02695', iid='P15889', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C68135', iid='P09616', r_ui=3.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C35623', iid='P24788', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C50622', iid='P30952', r_ui=1.0, est=3.092664705332318, details={'was_impossible': False}),
#  Prediction(uid='C40004', iid='P26992', r_ui=5.0, est=3.7679308667507994, details={'was_impossible': False}),
#  Prediction(uid='C81349', iid='P06690', r_ui=2.0, est=3.2611089285444725, details={'was_impossible': False}),
#  Prediction(uid='C24100', iid='P27848', r_ui=5.0, est=4.030567911103131, details={'was_impossible': False}),
#  Prediction(uid='C55346', iid='P08429', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C45058', iid='P06029', r_ui=1.0, est=1.6922403577452072, details={'was_impossible': False}),
#  Prediction(uid='C92953', iid='P02952', r_ui=2.0, est=4.04072433862786, details={'was_impossible': False}),
#  Prediction(uid='C43030', iid='P00513', r_ui=5.0, est=4.110810015372593, details={'was_impossible': False}),
#  Prediction(uid='C94578', iid='P18951', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C19283', iid='P32871', r_ui=4.0, est=3.743937079222513, details={'was_impossible': False}),
#  Prediction(uid='C20030', iid='P32786', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C22859', iid='P02828', r_ui=3.0, est=4.064607236683818, details={'was_impossible': False}),
#  Prediction(uid='C18994', iid='P25430', r_ui=4.0, est=3.331239254583171, details={'was_impossible': False}),
#  Prediction(uid='C77683', iid='P01492', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C90041', iid='P18033', r_ui=5.0, est=4.170827562588161, details={'was_impossible': False}),
#  Prediction(uid='C03719', iid='P25818', r_ui=4.0, est=3.7281048818443847, details={'was_impossible': False}),
#  Prediction(uid='C31019', iid='P12543', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C91784', iid='P32205', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C38625', iid='P00619', r_ui=1.0, est=1.800496289476044, details={'was_impossible': False}),
# ...
#  Prediction(uid='C02821', iid='P17569', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C82960', iid='P22999', r_ui=5.0, est=3.6855149934558744, details={'was_impossible': False}),
#  Prediction(uid='C81036', iid='P23741', r_ui=5.0, est=4.085385595261943, details={'was_impossible': False}),
#  Prediction(uid='C82229', iid='P26996', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C11132', iid='P30506', r_ui=1.0, est=2.933414608588247, details={'was_impossible': False}),
#  Prediction(uid='C77176', iid='P31712', r_ui=5.0, est=4.097570677351901, details={'was_impossible': False}),
#  Prediction(uid='C18538', iid='P12262', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C84204', iid='P16646', r_ui=4.0, est=3.735895047937914, details={'was_impossible': False}),
#  Prediction(uid='C42111', iid='P02863', r_ui=3.0, est=3.821748874195474, details={'was_impossible': False}),
#  Prediction(uid='C34167', iid='P03921', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C16550', iid='P28634', r_ui=1.0, est=3.542352400923385, details={'was_impossible': False}),
#  Prediction(uid='C34092', iid='P24571', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C85474', iid='P03086', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C14430', iid='P10205', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C68625', iid='P14960', r_ui=5.0, est=4.299011020085653, details={'was_impossible': False}),
#  Prediction(uid='C42824', iid='P05343', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C56225', iid='P04214', r_ui=3.0, est=4.668719920591936, details={'was_impossible': False}),
#  Prediction(uid='C35978', iid='P00709', r_ui=5.0, est=4.10610538304168, details={'was_impossible': False}),
#  Prediction(uid='C58666', iid='P05859', r_ui=1.0, est=2.9483591239368625, details={'was_impossible': False}),
#  Prediction(uid='C59958', iid='P18932', r_ui=4.0, est=3.7828079839993642, details={'was_impossible': False}),
#  Prediction(uid='C26283', iid='P04587', r_ui=5.0, est=4.296348153787851, details={'was_impossible': False}),
#  Prediction(uid='C25979', iid='P31861', r_ui=1.0, est=1.7090082949763306, details={'was_impossible': False}),
#  Prediction(uid='C54109', iid='P14414', r_ui=3.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C07588', iid='P01848', r_ui=5.0, est=3.7943365976538033, details={'was_impossible': False}),
#  Prediction(uid='C95732', iid='P03185', r_ui=4.0, est=3.676694148671711, details={'was_impossible': False}),
#  Prediction(uid='C55951', iid='P11313', r_ui=5.0, est=4.6274828143513025, details={'was_impossible': False}),
#  Prediction(uid='C61413', iid='P31170', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C36664', iid='P28669', r_ui=2.0, est=3.830497252748071, details={'was_impossible': False}),
#  Prediction(uid='C31417', iid='P19584', r_ui=1.0, est=2.5585811223925665, details={'was_impossible': False}),
#  Prediction(uid='C60972', iid='P15383', r_ui=5.0, est=2.8713575998108394, details={'was_impossible': False}),
#  Prediction(uid='C80867', iid='P22067', r_ui=5.0, est=4.100325709509867, details={'was_impossible': False}),
#  Prediction(uid='C87788', iid='P23804', r_ui=4.0, est=3.2357897906782407, details={'was_impossible': False}),
#  Prediction(uid='C91483', iid='P16573', r_ui=4.0, est=3.818654502809916, details={'was_impossible': False}),
#  Prediction(uid='C07242', iid='P12927', r_ui=1.0, est=3.732513877646447, details={'was_impossible': False}),
#  Prediction(uid='C38645', iid='P07899', r_ui=5.0, est=4.170910929766832, details={'was_impossible': False}),
#  Prediction(uid='C95382', iid='P11245', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C05653', iid='P25745', r_ui=2.0, est=3.149375379104896, details={'was_impossible': False}),
#  Prediction(uid='C06411', iid='P18539', r_ui=5.0, est=4.9153636447552795, details={'was_impossible': False}),
#  Prediction(uid='C02837', iid='P11481', r_ui=1.0, est=2.64841048742809, details={'was_impossible': False}),
#  Prediction(uid='C84223', iid='P01121', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C56568', iid='P30260', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C08198', iid='P10184', r_ui=1.0, est=4.076118671442614, details={'was_impossible': False}),
#  Prediction(uid='C11686', iid='P13456', r_ui=1.0, est=2.993823637464263, details={'was_impossible': False}),
#  Prediction(uid='C67196', iid='P21567', r_ui=1.0, est=4.300736044154026, details={'was_impossible': False}),
#  Prediction(uid='C55004', iid='P15064', r_ui=5.0, est=3.5408940092658603, details={'was_impossible': False}),
#  Prediction(uid='C77554', iid='P11272', r_ui=2.0, est=4.046983505572813, details={'was_impossible': False}),
#  Prediction(uid='C04815', iid='P14810', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C25310', iid='P11286', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C83597', iid='P16438', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C36951', iid='P26460', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C95603', iid='P27347', r_ui=1.0, est=2.6240551833243684, details={'was_impossible': False}),
#  Prediction(uid='C15981', iid='P14521', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C68212', iid='P15518', r_ui=5.0, est=3.9336472998436536, details={'was_impossible': False}),
#  Prediction(uid='C11779', iid='P25818', r_ui=4.0, est=3.7281048818443847, details={'was_impossible': False}),
#  Prediction(uid='C32074', iid='P25028', r_ui=4.0, est=3.377033661601349, details={'was_impossible': False}),
#  Prediction(uid='C89724', iid='P09565', r_ui=3.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C32898', iid='P29018', r_ui=1.0, est=3.1173150337861273, details={'was_impossible': False}),
#  Prediction(uid='C06353', iid='P27354', r_ui=5.0, est=3.661893533165519, details={'was_impossible': False}),
#  Prediction(uid='C40360', iid='P19495', r_ui=1.0, est=2.9166288905578472, details={'was_impossible': False}),
#  Prediction(uid='C23305', iid='P02127', r_ui=5.0, est=3.6479001532157453, details={'was_impossible': False}),
#  Prediction(uid='C91882', iid='P23509', r_ui=1.0, est=2.8387640407194987, details={'was_impossible': False}),
#  Prediction(uid='C53443', iid='P13871', r_ui=2.0, est=3.0031494330600417, details={'was_impossible': False}),
#  Prediction(uid='C89196', iid='P13860', r_ui=5.0, est=4.321777187910692, details={'was_impossible': False}),
#  Prediction(uid='C50268', iid='P13619', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C86783', iid='P15670', r_ui=5.0, est=4.317515599926394, details={'was_impossible': False}),
#  Prediction(uid='C49751', iid='P07342', r_ui=2.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C38231', iid='P21235', r_ui=4.0, est=3.8282827447541568, details={'was_impossible': False}),
#  Prediction(uid='C30288', iid='P28011', r_ui=2.0, est=3.8105569591817043, details={'was_impossible': False}),
#  Prediction(uid='C16749', iid='P01908', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C39818', iid='P06326', r_ui=1.0, est=2.265177068035893, details={'was_impossible': False}),
#  Prediction(uid='C66919', iid='P05341', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C29553', iid='P17983', r_ui=5.0, est=4.110099819327893, details={'was_impossible': False}),
#  Prediction(uid='C01041', iid='P11478', r_ui=5.0, est=3.1478488409722267, details={'was_impossible': False}),
#  Prediction(uid='C88005', iid='P05880', r_ui=2.0, est=3.049715673716605, details={'was_impossible': False}),
#  Prediction(uid='C18423', iid='P29967', r_ui=4.0, est=4.586951007737479, details={'was_impossible': False}),
#  Prediction(uid='C29591', iid='P19199', r_ui=4.0, est=3.8162291508828687, details={'was_impossible': False}),
#  Prediction(uid='C21395', iid='P21971', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C57922', iid='P23891', r_ui=5.0, est=4.284402773621604, details={'was_impossible': False}),
#  Prediction(uid='C47076', iid='P23744', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C82126', iid='P07406', r_ui=3.0, est=3.504505860561891, details={'was_impossible': False}),
#  Prediction(uid='C56327', iid='P11897', r_ui=1.0, est=2.6165939230416946, details={'was_impossible': False}),
#  Prediction(uid='C93580', iid='P18418', r_ui=5.0, est=4.197712822894931, details={'was_impossible': False}),
#  Prediction(uid='C37870', iid='P19290', r_ui=2.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C49181', iid='P08940', r_ui=3.0, est=4.241006205737769, details={'was_impossible': False}),
#  Prediction(uid='C17892', iid='P26058', r_ui=3.0, est=3.6607862120992443, details={'was_impossible': False}),
#  Prediction(uid='C17597', iid='P05473', r_ui=5.0, est=4.049607426629571, details={'was_impossible': False}),
#  Prediction(uid='C54004', iid='P26401', r_ui=5.0, est=4.305065701941562, details={'was_impossible': False}),
#  Prediction(uid='C93859', iid='P16650', r_ui=1.0, est=3.0780994927220755, details={'was_impossible': False}),
#  Prediction(uid='C06898', iid='P17097', r_ui=5.0, est=4.287149617464727, details={'was_impossible': False}),
#  Prediction(uid='C35877', iid='P29981', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C31215', iid='P05448', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C69221', iid='P29093', r_ui=5.0, est=4.323709770439173, details={'was_impossible': False}),
#  Prediction(uid='C44339', iid='P27630', r_ui=5.0, est=4.140786128881801, details={'was_impossible': False}),
#  Prediction(uid='C29158', iid='P22673', r_ui=5.0, est=4.964006729275739, details={'was_impossible': False}),
#  Prediction(uid='C00044', iid='P22828', r_ui=4.0, est=4.101158544086164, details={'was_impossible': False}),
#  Prediction(uid='C83685', iid='P18593', r_ui=3.0, est=3.837518214800848, details={'was_impossible': False}),
#  Prediction(uid='C78592', iid='P32583', r_ui=5.0, est=4.148866110744593, details={'was_impossible': False}),
#  Prediction(uid='C09274', iid='P28028', r_ui=5.0, est=4.061470841683796, details={'was_impossible': False}),
#  Prediction(uid='C50794', iid='P00251', r_ui=2.0, est=3.027731820800505, details={'was_impossible': False}),
#  Prediction(uid='C22163', iid='P00550', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C91555', iid='P12557', r_ui=5.0, est=3.5838929579741787, details={'was_impossible': False}),
#  Prediction(uid='C26887', iid='P19475', r_ui=1.0, est=2.9603460560076953, details={'was_impossible': False}),
#  Prediction(uid='C17572', iid='P20893', r_ui=5.0, est=4.088795589353173, details={'was_impossible': False}),
#  Prediction(uid='C68314', iid='P07907', r_ui=5.0, est=3.6771544955172124, details={'was_impossible': False}),
#  Prediction(uid='C92405', iid='P20450', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C60154', iid='P22237', r_ui=3.0, est=3.420979199652499, details={'was_impossible': False}),
#  Prediction(uid='C30137', iid='P05647', r_ui=5.0, est=4.009147413755393, details={'was_impossible': False}),
#  Prediction(uid='C76986', iid='P21201', r_ui=1.0, est=4.30808030844519, details={'was_impossible': False}),
#  Prediction(uid='C48041', iid='P05591', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C41756', iid='P06942', r_ui=5.0, est=4.164354692736807, details={'was_impossible': False}),
#  Prediction(uid='C55826', iid='P27391', r_ui=4.0, est=4.265139295179934, details={'was_impossible': False}),
#  Prediction(uid='C63476', iid='P22519', r_ui=5.0, est=4.359768259490522, details={'was_impossible': False}),
#  Prediction(uid='C01072', iid='P00864', r_ui=5.0, est=3.9119225635437322, details={'was_impossible': False}),
#  Prediction(uid='C61218', iid='P04784', r_ui=5.0, est=4.230060858052291, details={'was_impossible': False}),
#  Prediction(uid='C55177', iid='P05607', r_ui=3.0, est=3.779339005093081, details={'was_impossible': False}),
#  Prediction(uid='C68198', iid='P15337', r_ui=5.0, est=4.0887011983610195, details={'was_impossible': False}),
#  Prediction(uid='C90931', iid='P29699', r_ui=3.0, est=3.049944237385109, details={'was_impossible': False}),
#  Prediction(uid='C12770', iid='P19062', r_ui=5.0, est=4.123269708571456, details={'was_impossible': False}),
#  Prediction(uid='C86097', iid='P32183', r_ui=1.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C17869', iid='P03185', r_ui=1.0, est=2.917571881974239, details={'was_impossible': False}),
#  Prediction(uid='C16934', iid='P27603', r_ui=5.0, est=4.100790904773643, details={'was_impossible': False}),
#  Prediction(uid='C89327', iid='P21319', r_ui=4.0, est=3.586595345230355, details={'was_impossible': False}),
#  Prediction(uid='C13860', iid='P18927', r_ui=4.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C14807', iid='P27961', r_ui=1.0, est=2.649064311528019, details={'was_impossible': False}),
#  Prediction(uid='C83259', iid='P03537', r_ui=5.0, est=4.105400335950157, details={'was_impossible': False}),
#  Prediction(uid='C66819', iid='P04290', r_ui=3.0, est=3.5983486659912103, details={'was_impossible': False}),
#  Prediction(uid='C77641', iid='P32539', r_ui=5.0, est=4.4464872885920075, details={'was_impossible': False}),
#  Prediction(uid='C68640', iid='P20061', r_ui=5.0, est=4.893251194554438, details={'was_impossible': False}),
#  Prediction(uid='C33619', iid='P04117', r_ui=2.0, est=3.2499415328011, details={'was_impossible': False}),
#  Prediction(uid='C70319', iid='P22494', r_ui=2.0, est=3.801072452748831, details={'was_impossible': False}),
#  Prediction(uid='C08634', iid='P15446', r_ui=3.0, est=3.5310013154571256, details={'was_impossible': False}),
#  Prediction(uid='C91598', iid='P15960', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C45130', iid='P05473', r_ui=5.0, est=4.408572877342544, details={'was_impossible': False}),
#  Prediction(uid='C50169', iid='P07257', r_ui=4.0, est=3.326616099356629, details={'was_impossible': False}),
#  Prediction(uid='C08401', iid='P06491', r_ui=4.0, est=4.368038586376948, details={'was_impossible': False}),
#  Prediction(uid='C68607', iid='P00838', r_ui=3.0, est=3.6904378207148922, details={'was_impossible': False}),
#  Prediction(uid='C87745', iid='P03934', r_ui=3.0, est=4.654951963853348, details={'was_impossible': False}),
#  Prediction(uid='C77122', iid='P18273', r_ui=3.0, est=3.6397414853885532, details={'was_impossible': False}),
#  Prediction(uid='C53996', iid='P00251', r_ui=5.0, est=4.153094887322255, details={'was_impossible': False}),
#  Prediction(uid='C70514', iid='P14757', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  Prediction(uid='C14281', iid='P11101', r_ui=1.0, est=3.6752697137476105, details={'was_impossible': False}),
#  Prediction(uid='C54056', iid='P29347', r_ui=5.0, est=4.098673914852029, details={'was_impossible': False}),
#  Prediction(uid='C43545', iid='P15533', r_ui=3.0, est=3.456798201630995, details={'was_impossible': False}),
#  Prediction(uid='C20029', iid='P27553', r_ui=4.0, est=3.6790303598481655, details={'was_impossible': False}),
#  Prediction(uid='C73024', iid='P25931', r_ui=3.0, est=3.0694810752577464, details={'was_impossible': False}),
#  Prediction(uid='C93326', iid='P11800', r_ui=5.0, est=3.7392430399893084, details={'was_impossible': False}),
#  ...]

# %%
full_df
# Out:
#          index  Unnamed: 0  Unnamed: 0.1 order_id  payment_sequential  \
# 0            9           9             9  ON56470                   1
# 1           10          10            10  ON56470                   1
# 2           14          14            14  ON34004                   1
# 3           37          37            37  ON25811                   1
# 4           38          38            38  ON25811                   1
# ...        ...         ...           ...      ...                 ...
# 100846  100840      100840        100840  ON72948                   1
# 100847  100846      100846        100846  ON20609                   1
# 100848  100848      100848        100848  ON12593                   1
# 100849  100849      100849        100849  ON17375                   1
# 100850  100850      100850        100850  ON72563                   1
#
#        payment_type  payment_installments order_status  \
# 0       credit_card                    10    delivered
# 1       credit_card                    10    delivered
# 2            boleto                     1    delivered
# 3       credit_card                     1    delivered
# 4       credit_card                     1    delivered
# ...             ...                   ...          ...
# 100846       boleto                     1    delivered
# 100847  credit_card                     7    delivered
# 100848  credit_card                     6    delivered
# 100849  credit_card                     8    delivered
# 100850  credit_card                     1    delivered
#
#        order_purchase_timestamp order_estimated_delivery_date  ...  review_id  \
# 0              11/28/2017 16:27               12/18/2017 0:00  ...    PR80991
# 1              11/28/2017 16:27               12/18/2017 0:00  ...    PR80991
# 2                8/4/2018 14:40                8/10/2018 0:00  ...    PR08376
# 3               7/27/2018 13:11                8/15/2018 0:00  ...    PR59952
# 4               7/27/2018 13:11                8/15/2018 0:00  ...    PR59952
# ...                         ...                           ...  ...        ...
# 100846           6/2/2018 20:13                7/13/2018 0:00  ...    PR75573
# 100847          2/28/2018 10:14                3/27/2018 0:00  ...    PR28493
# 100848          4/23/2017 16:59                5/17/2017 0:00  ...    PR73958
# 100849          2/18/2018 17:33                3/12/2018 0:00  ...    PR43440
# 100850           5/4/2018 13:18                5/23/2018 0:00  ...    PR60184
#
#        review_score  review_comment_title  \
# 0                 5                   NaN
# 1                 5                   NaN
# 2                 4                   Bom
# 3                 5       super recomendo
# 4                 5       super recomendo
# ...             ...                   ...
# 100846            5             Recomendo
# 100847            5                   NaN
# 100848            5                   NaN
# 100849            3                   NaN
# 100850            5                   NaN
#
#                                    review_comment_message  \
# 0       produto ótimo tudo muito bom só uma coisa eu n...
# 1       produto ótimo tudo muito bom só uma coisa eu n...
# 2                        Chegou atrasado mas está valendo
# 3                 Produto exatamente conforme solicitação
# 4                 Produto exatamente conforme solicitação
# ...                                                   ...
# 100846  Muito bom o processo de compra, sem imprevisto...
# 100847       otimos produtos \r\ntudo ok\r\nshow de bola
# 100848                                                NaN
# 100849  Excelente produto, correto, bem embalado mas c...
# 100850                                                NaN
#
#        review_creation_date review_answer_timestamp total_payment  \
# 0           12/16/2017 0:00        12/18/2017 11:16        520.24
# 1           12/16/2017 0:00        12/18/2017 11:16        520.24
# 2            8/15/2018 0:00          8/17/2018 5:10        126.23
# 3             8/1/2018 0:00          8/3/2018 18:00       1037.44
# 4             8/1/2018 0:00          8/3/2018 18:00       1037.44
# ...                     ...                     ...           ...
# 100846       6/15/2018 0:00          6/19/2018 2:35         52.75
# 100847       3/27/2018 0:00          4/3/2018 14:51         96.80
# 100848        5/4/2017 0:00          5/7/2017 11:30        237.14
# 100849        3/6/2018 0:00          3/6/2018 15:39        165.80
# 100850       5/13/2018 0:00          5/14/2018 1:43         69.90
#
#                                              product_name  \
# 0                            Wheat Free Blueberry Muffins
# 1            Kellogg's Pop-Tarts Frosted S'mores Pastries
# 2                     100% Recycled 1-Ply Bathroom Tissue
# 3       Ultra Comfort Care 2-Ply Double Rolls Toilet P...
# 4                              Chorizo Hemp Soy-Free Tofu
# ...                                                   ...
# 100846                              L/s sol patrol shirt
# 100847                   Frappuccino Chilled Coffee Drink
# 100848                       Borderless messenger shorts
# 100849              Tall Kitchen Bags, Handle-Tie, 13 Gal
# 100850                       Toasted Buttercrisp Crackers
#
#         product_category_new  repeater
# 0             Love with food         1
# 1             Love with food         1
# 2                   MunchPak         1
# 3            packaged cheese         1
# 4            packaged cheese         1
# ...                      ...       ...
# 100846     spices seasonings         0
# 100847          Hand Luggage         0
# 100848         Apple Macbook         0
# 100849              Perfumes         0
# 100850        frozen produce         0
#
# [100851 rows x 43 columns]

# %%
def get_Iu(uid):
    """Return the number of items rated by given user
    
    Args:
        uid: The raw id of the user.
    Returns:
        The number of items rated by the user.
    """
    
    try:
        return len(train_set.ur[train_set.to_inner_uid(uid)])
    except ValueError:  # user was not part of the trainset
        return 0
    
def get_Ui(iid):
    """Return the number of users that have rated given item
    
    Args:
        iid: The raw id of the item.
    Returns:
        The number of users that have rated the item.
    """
    
    try:
        return len(train_set.ir[train_set.to_inner_iid(iid)])
    except ValueError:  # item was not part of the trainset
        return 0

recommendation_results = pd.DataFrame(final_predictions, columns=['uid', 'iid', 'rui', 'est', 'details'])    
recommendation_results['No. of items rated by user'] = recommendation_results.uid.apply(get_Iu)
recommendation_results['No. of users that rated this item'] = recommendation_results.iid.apply(get_Ui)
recommendation_results['error'] = abs(recommendation_results.est - recommendation_results.rui)

# %%
recommendation_results.shape
# Out:
# (1742, 8)

# %% [markdown]
# # Analysis of prediction based on errors

# %%
best_predictions = recommendation_results.sort_values(by='error')[:10]
worst_predictions = recommendation_results.sort_values(by='error')[-10:]

# %%
best_predictions
# Out:
#          uid     iid  rui       est                    details  \
# 1408  C92489  P23910  5.0  5.000000  {'was_impossible': False}
# 1714  C15587  P10414  5.0  5.000000  {'was_impossible': False}
# 232   C20235  P06328  4.0  4.009678  {'was_impossible': False}
# 1466  C70254  P09732  4.0  3.988124  {'was_impossible': False}
# 1446  C10952  P23526  4.0  3.984769  {'was_impossible': False}
# 1049  C90020  P31284  3.0  2.984054  {'was_impossible': False}
# 154   C07277  P28011  4.0  3.980652  {'was_impossible': False}
# 496   C87468  P05972  3.0  2.977820  {'was_impossible': False}
# 1110  C82781  P06299  4.0  3.977018  {'was_impossible': False}
# 1094  C00310  P14318  4.0  3.975376  {'was_impossible': False}
#
#       No. of items rated by user  No. of users that rated this item     error
# 1408                           5                                  1  0.000000
# 1714                           3                                  2  0.000000
# 232                            1                                  0  0.009678
# 1466                           1                                  8  0.011876
# 1446                           1                                  0  0.015231
# 1049                           0                                  1  0.015946
# 154                            1                                 84  0.019348
# 496                            0                                  1  0.022180
# 1110                           1                                 10  0.022982
# 1094                           1                                  0  0.024624

# %%
worst_predictions
# Out:
#          uid     iid  rui       est                    details  \
# 1030  C32141  P25453  1.0  4.220995  {'was_impossible': False}
# 783   C25202  P14507  1.0  4.261180  {'was_impossible': False}
# 448   C19855  P10728  1.0  4.282968  {'was_impossible': False}
# 1028  C86348  P32601  1.0  4.296241  {'was_impossible': False}
# 897   C67196  P21567  1.0  4.300736  {'was_impossible': False}
# 961   C76986  P21201  1.0  4.308080  {'was_impossible': False}
# 1200  C93478  P08816  1.0  4.353003  {'was_impossible': False}
# 1189  C28391  P09927  1.0  4.441366  {'was_impossible': False}
# 542   C92485  P04555  1.0  4.482375  {'was_impossible': False}
# 1502  C40637  P02786  1.0  4.516282  {'was_impossible': False}
#
#       No. of items rated by user  No. of users that rated this item     error
# 1030                           0                                  2  3.220995
# 783                            0                                  7  3.261180
# 448                            0                                  2  3.282968
# 1028                           0                                  2  3.296241
# 897                            0                                  2  3.300736
# 961                            0                                  3  3.308080
# 1200                           1                                  0  3.353003
# 1189                           0                                  3  3.441366
# 542                            2                                  0  3.482375
# 1502                           1                                 31  3.516282

# %%
recommendation_results1 = recommendation_results.copy()

# %%
recommendation_results1.rename(columns={'iid':'productId'}, inplace=True)

# %%
recommendation_results_new = pd.merge(recommendation_results1, new, on='productId', how='left')

# %%
recommendation_results_new
# Out:
#          uid productId  rui       est                    details  \
# 0     C71088    P10025  5.0  4.326070  {'was_impossible': False}
# 1     C88921    P14134  3.0  3.242378  {'was_impossible': False}
# 2     C92824    P28011  5.0  4.455684  {'was_impossible': False}
# 3     C31650    P10696  4.0  3.523533  {'was_impossible': False}
# 4     C61824    P22999  4.0  3.493849  {'was_impossible': False}
# ...      ...       ...  ...       ...                        ...
# 1737  C36446    P01384  5.0  4.580790  {'was_impossible': False}
# 1738  C05429    P03621  2.5  3.390880  {'was_impossible': False}
# 1739  C07393    P25680  3.0  2.570339  {'was_impossible': False}
# 1740  C95427    P03185  1.0  3.676694  {'was_impossible': False}
# 1741  C60720    P21993  5.0  4.545372  {'was_impossible': False}
#
#       No. of items rated by user  No. of users that rated this item     error  \
# 0                              2                                  0  0.673930
# 1                              0                                  1  0.242378
# 2                              1                                 84  0.544316
# 3                              0                                  1  0.476467
# 4                              1                                  6  0.506151
# ...                          ...                                ...       ...
# 1737                           1                                 18  0.419210
# 1738                           1                                  0  0.890880
# 1739                           0                                  2  0.429661
# 1740                           0                                 76  2.676694
# 1741                           4                                  0  0.454628
#
#                                            product_name
# 0                  Noodle Soup, Shin Cup, Gourmet Spicy
# 1     Flatbread Pizza All Natural Tomato Sauce Pizza...
# 2                         Clotted Cream, English Luxury
# 3                            Organic Raisin Bran Cereal
# 4                                   Vanilla Coconutmilk
# ...                                                 ...
# 1737                Yours Truly Chocolate Covered Cones
# 1738                       Parmigiano Reggiano Marinara
# 1739                          Premium Pork Sage Sausage
# 1740  Crystals Lavender Blossom In-Wash Fragrance Bo...
# 1741                   Boneless Skinless Chicken Breast
#
# [1742 rows x 9 columns]

# %%
disp_rec = recommendation_results_new.copy()

# %%
disp_rec
# Out:
#          uid productId  rui       est                    details  \
# 0     C71088    P10025  5.0  4.326070  {'was_impossible': False}
# 1     C88921    P14134  3.0  3.242378  {'was_impossible': False}
# 2     C92824    P28011  5.0  4.455684  {'was_impossible': False}
# 3     C31650    P10696  4.0  3.523533  {'was_impossible': False}
# 4     C61824    P22999  4.0  3.493849  {'was_impossible': False}
# ...      ...       ...  ...       ...                        ...
# 1737  C36446    P01384  5.0  4.580790  {'was_impossible': False}
# 1738  C05429    P03621  2.5  3.390880  {'was_impossible': False}
# 1739  C07393    P25680  3.0  2.570339  {'was_impossible': False}
# 1740  C95427    P03185  1.0  3.676694  {'was_impossible': False}
# 1741  C60720    P21993  5.0  4.545372  {'was_impossible': False}
#
#       No. of items rated by user  No. of users that rated this item     error  \
# 0                              2                                  0  0.673930
# 1                              0                                  1  0.242378
# 2                              1                                 84  0.544316
# 3                              0                                  1  0.476467
# 4                              1                                  6  0.506151
# ...                          ...                                ...       ...
# 1737                           1                                 18  0.419210
# 1738                           1                                  0  0.890880
# 1739                           0                                  2  0.429661
# 1740                           0                                 76  2.676694
# 1741                           4                                  0  0.454628
#
#                                            product_name
# 0                  Noodle Soup, Shin Cup, Gourmet Spicy
# 1     Flatbread Pizza All Natural Tomato Sauce Pizza...
# 2                         Clotted Cream, English Luxury
# 3                            Organic Raisin Bran Cereal
# 4                                   Vanilla Coconutmilk
# ...                                                 ...
# 1737                Yours Truly Chocolate Covered Cones
# 1738                       Parmigiano Reggiano Marinara
# 1739                          Premium Pork Sage Sausage
# 1740  Crystals Lavender Blossom In-Wash Fragrance Bo...
# 1741                   Boneless Skinless Chicken Breast
#
# [1742 rows x 9 columns]

# %%
del disp_rec['rui']
del disp_rec['est']
del disp_rec['details']

# %%
disp_rec
# Out:
#          uid productId  No. of items rated by user  \
# 0     C71088    P10025                           2
# 1     C88921    P14134                           0
# 2     C92824    P28011                           1
# 3     C31650    P10696                           0
# 4     C61824    P22999                           1
# ...      ...       ...                         ...
# 1737  C36446    P01384                           1
# 1738  C05429    P03621                           1
# 1739  C07393    P25680                           0
# 1740  C95427    P03185                           0
# 1741  C60720    P21993                           4
#
#       No. of users that rated this item     error  \
# 0                                     0  0.673930
# 1                                     1  0.242378
# 2                                    84  0.544316
# 3                                     1  0.476467
# 4                                     6  0.506151
# ...                                 ...       ...
# 1737                                 18  0.419210
# 1738                                  0  0.890880
# 1739                                  2  0.429661
# 1740                                 76  2.676694
# 1741                                  0  0.454628
#
#                                            product_name
# 0                  Noodle Soup, Shin Cup, Gourmet Spicy
# 1     Flatbread Pizza All Natural Tomato Sauce Pizza...
# 2                         Clotted Cream, English Luxury
# 3                            Organic Raisin Bran Cereal
# 4                                   Vanilla Coconutmilk
# ...                                                 ...
# 1737                Yours Truly Chocolate Covered Cones
# 1738                       Parmigiano Reggiano Marinara
# 1739                          Premium Pork Sage Sausage
# 1740  Crystals Lavender Blossom In-Wash Fragrance Bo...
# 1741                   Boneless Skinless Chicken Breast
#
# [1742 rows x 6 columns]

# %%
best_predictions1 = disp_rec.sort_values(by='error')[:10]

# %%
worst_predictions1 = disp_rec.sort_values(by='error')[-10:]

# %%
best_predictions1
# Out:
#          uid productId  No. of items rated by user  \
# 1408  C92489    P23910                           5
# 1714  C15587    P10414                           3
# 232   C20235    P06328                           1
# 1466  C70254    P09732                           1
# 1446  C10952    P23526                           1
# 1049  C90020    P31284                           0
# 154   C07277    P28011                           1
# 496   C87468    P05972                           0
# 1110  C82781    P06299                           1
# 1094  C00310    P14318                           1
#
#       No. of users that rated this item     error  \
# 1408                                  1  0.000000
# 1714                                  2  0.000000
# 232                                   0  0.009678
# 1466                                  8  0.011876
# 1446                                  0  0.015231
# 1049                                  1  0.015946
# 154                                  84  0.019348
# 496                                   1  0.022180
# 1110                                 10  0.022982
# 1094                                  0  0.024624
#
#                                        product_name
# 1408                             Syrup Special Dark
# 1714    Chunky Blend Vegetable Beef Pilaf Baby Food
# 232                Caramel Macchiato Coffee Creamer
# 1466                       Everything Inside Bagels
# 1446                          Alcoholic Ginger Beer
# 1049                       African Hot Pepper Sauce
# 154                   Clotted Cream, English Luxury
# 496                          Cheese Tortellini Soup
# 1110                          Champagne Vinaigrette
# 1094  100% Raw Coconut Water With Fair Trade Coffee

# %%
worst_predictions1
# Out:
#          uid productId  No. of items rated by user  \
# 1030  C32141    P25453                           0
# 783   C25202    P14507                           0
# 448   C19855    P10728                           0
# 1028  C86348    P32601                           0
# 897   C67196    P21567                           0
# 961   C76986    P21201                           0
# 1200  C93478    P08816                           1
# 1189  C28391    P09927                           0
# 542   C92485    P04555                           2
# 1502  C40637    P02786                           1
#
#       No. of users that rated this item     error  \
# 1030                                  2  3.220995
# 783                                   7  3.261180
# 448                                   2  3.282968
# 1028                                  2  3.296241
# 897                                   2  3.300736
# 961                                   3  3.308080
# 1200                                  0  3.353003
# 1189                                  3  3.441366
# 542                                   0  3.482375
# 1502                                 31  3.516282
#
#                                            product_name
# 1030                            Original Wheat Crackers
# 783                                   Turkey Drumsticks
# 448                                Angus Beef Meatballs
# 1028                              Hardwood Floor Polish
# 897                                   Lemonade With Tea
# 961                                   Whole Kernel Corn
# 1200  Jalapeño String Cheese, Low Moisture Part Skim...
# 1189            Stock In A Box All Natural Veggie Stock
# 542                               Classic Clean Shampoo
# 1502                    Sheep Milk Original Plain Kefir

# %%
disp_rec_repeat = pd.concat(g for _, g in disp_rec.groupby("uid") if len(g) > 1)

# %%
disp_rec_repeat
# Out:
#          uid productId  No. of items rated by user  \
# 227   C00182    P29511                           0
# 1233  C00182    P06909                           0
# 1216  C01804    P03339                           0
# 1522  C01804    P07513                           0
# 406   C02695    P03548                           0
# ...      ...       ...                         ...
# 1424  C91198    P24413                           0
# 790   C95823    P19760                           1
# 1025  C95823    P23134                           1
# 316   C95847    P19481                           0
# 1631  C95847    P25745                           0
#
#       No. of users that rated this item     error  \
# 227                                   0  1.260757
# 1233                                  0  1.260757
# 1216                                  0  1.260757
# 1522                                  0  1.260757
# 406                                   2  0.209119
# ...                                 ...       ...
# 1424                                  0  0.260757
# 790                                   2  1.438887
# 1025                                  0  2.049320
# 316                                   0  2.739243
# 1631                                 80  2.828509
#
#                                            product_name
# 227                      Farmhouse Pancake & Waffle Mix
# 1233                            Chocolate Chunk Brownie
# 1216                                      Zingers Cakes
# 1522                         Rosemary Parmesan Crackers
# 406                            Hot Thick & Chunky Salsa
# ...                                                 ...
# 1424         Hardwood Slow Smoked Signature Pulled Pork
# 790                Organic Potato Quinoa & Spinach Soup
# 1025  Baked Scalloped Potatoes With Real Cheddar Che...
# 316           Original Chocolate Flavor Fat Free  Syrup
# 1631                                   Corn Pops Cereal
#
# [147 rows x 6 columns]

# %%
dups_color = disp_rec_repeat.pivot_table(index=['uid'], aggfunc='size')

# %%
dups_color.loc[dups_color.values == 2]
# Out:
# uid
# C00182    2
# C01804    2
# C02695    2
# C06411    2
# C08634    2
#          ..
# C89967    2
# C90165    2
# C91198    2
# C95823    2
# C95847    2
# Length: 70, dtype: int64

# %%
disp_rec
# Out:
#          uid productId  No. of items rated by user  \
# 0     C71088    P10025                           2
# 1     C88921    P14134                           0
# 2     C92824    P28011                           1
# 3     C31650    P10696                           0
# 4     C61824    P22999                           1
# ...      ...       ...                         ...
# 1737  C36446    P01384                           1
# 1738  C05429    P03621                           1
# 1739  C07393    P25680                           0
# 1740  C95427    P03185                           0
# 1741  C60720    P21993                           4
#
#       No. of users that rated this item     error  \
# 0                                     0  0.673930
# 1                                     1  0.242378
# 2                                    84  0.544316
# 3                                     1  0.476467
# 4                                     6  0.506151
# ...                                 ...       ...
# 1737                                 18  0.419210
# 1738                                  0  0.890880
# 1739                                  2  0.429661
# 1740                                 76  2.676694
# 1741                                  0  0.454628
#
#                                            product_name
# 0                  Noodle Soup, Shin Cup, Gourmet Spicy
# 1     Flatbread Pizza All Natural Tomato Sauce Pizza...
# 2                         Clotted Cream, English Luxury
# 3                            Organic Raisin Bran Cereal
# 4                                   Vanilla Coconutmilk
# ...                                                 ...
# 1737                Yours Truly Chocolate Covered Cones
# 1738                       Parmigiano Reggiano Marinara
# 1739                          Premium Pork Sage Sausage
# 1740  Crystals Lavender Blossom In-Wash Fragrance Bo...
# 1741                   Boneless Skinless Chicken Breast
#
# [1742 rows x 6 columns]

# %%
disp_rec.loc[disp_rec['uid'] == 'C40402']
# Out:
#          uid productId  No. of items rated by user  \
# 185   C40402    P13659                           1
# 398   C40402    P28873                           1
# 485   C40402    P26306                           1
# 1184  C40402    P15903                           1
#
#       No. of users that rated this item     error  \
# 185                                   0  0.914416
# 398                                   0  0.914416
# 485                                   0  0.914416
# 1184                                  0  0.914416
#
#                                      product_name
# 185   Stage 2 Sweet Potato Corn & Apple Baby Food
# 398          Nacho Cheese Flavored Tortilla Chips
# 485                                      Pretzels
# 1184            Pearl Plastic Unscented Multipack

# %%
disp_rec.loc[disp_rec['uid'] == 'C56568']
# Out:
#          uid productId  No. of items rated by user  \
# 380   C56568    P06598                           0
# 894   C56568    P30260                           0
# 1518  C56568    P09677                           0
#
#       No. of users that rated this item     error  \
# 380                                   0  1.260757
# 894                                   0  1.260757
# 1518                                  0  1.260757
#
#                                  product_name
# 380                                   Kumquat
# 894           Cut Crystal 10\" Plastic Plates
# 1518  Organic Vitality Snack Green Magic Chia

# %%
disp_rec.loc[disp_rec['uid'] == 'C00182']
# Out:
#          uid productId  No. of items rated by user  \
# 227   C00182    P29511                           0
# 1233  C00182    P06909                           0
#
#       No. of users that rated this item     error  \
# 227                                   0  1.260757
# 1233                                  0  1.260757
#
#                         product_name
# 227   Farmhouse Pancake & Waffle Mix
# 1233         Chocolate Chunk Brownie

# %%
disp_rec.loc[disp_rec['uid'] == 'C01804']
# Out:
#          uid productId  No. of items rated by user  \
# 1216  C01804    P03339                           0
# 1522  C01804    P07513                           0
#
#       No. of users that rated this item     error                product_name
# 1216                                  0  1.260757               Zingers Cakes
# 1522                                  0  1.260757  Rosemary Parmesan Crackers

# %%
disp_rec.to_pickle('disp_rec.pkl')

# %%
best_predictions1.to_pickle('best_pred.pkl')

# %%
worst_predictions1.to_pickle('worst_pred.pkl')

# %%
full_df.to_pickle('full_df.pkl')

# %%
# plot model error
plt.figure(figsize=(12,5))
plt.hist(recommendation_results.error, color=olist_blue, bins=20)
plt.xlabel('Error (RMSE)', size=16)
plt.ylabel('Count', size=14)
plt.title('Distribution of Recommender Errors', size=14)
sns.despine();

# %%
def means_per_rating_group(dataset):
    real_over_three = dataset[dataset.rui > 3].error
    real_three_under = dataset[dataset.rui <= 3].error
    
    print("Overall recommendation system mean error:", dataset.error.mean())
    print("Mean error for products where user rates above 3:", real_over_three.mean())
    print("Mean error for products where user rates below 3:", real_three_under.mean())
    
    return real_over_three, real_three_under

real_over_three, real_three_under = means_per_rating_group(recommendation_results1)
# Out:
# Overall recommendation system mean error: 1.1689018902578308
# Mean error for products where user rates above 3: 0.8644173279773225
# Mean error for products where user rates below 3: 1.739684832090598

# %% [markdown]
# # Plot the recommendation system mean for users who rate products higher than 3 and lower than 3

# %%
plt.figure(figsize=(12,5))
plt.hist(real_over_three, bins=20, color=olist_blue, label='Actual Rating >3')
plt.hist(real_three_under, bins=20, color=olist_green, alpha=.8, label='Actual Rating <=3')
plt.xlabel('Error (RMSE)', size=16)
plt.ylabel('Count', size=14)
plt.title('Distribution of Recommender Errors', size=14)
sns.despine();

# %%
recommendation_results_final = recommendation_results.copy()

# %%
recommendation_results_final
# Out:
#          uid     iid  rui       est                    details  \
# 0     C71088  P10025  5.0  4.326070  {'was_impossible': False}
# 1     C88921  P14134  3.0  3.242378  {'was_impossible': False}
# 2     C92824  P28011  5.0  4.455684  {'was_impossible': False}
# 3     C31650  P10696  4.0  3.523533  {'was_impossible': False}
# 4     C61824  P22999  4.0  3.493849  {'was_impossible': False}
# ...      ...     ...  ...       ...                        ...
# 1737  C36446  P01384  5.0  4.580790  {'was_impossible': False}
# 1738  C05429  P03621  2.5  3.390880  {'was_impossible': False}
# 1739  C07393  P25680  3.0  2.570339  {'was_impossible': False}
# 1740  C95427  P03185  1.0  3.676694  {'was_impossible': False}
# 1741  C60720  P21993  5.0  4.545372  {'was_impossible': False}
#
#       No. of items rated by user  No. of users that rated this item     error
# 0                              2                                  0  0.673930
# 1                              0                                  1  0.242378
# 2                              1                                 84  0.544316
# 3                              0                                  1  0.476467
# 4                              1                                  6  0.506151
# ...                          ...                                ...       ...
# 1737                           1                                 18  0.419210
# 1738                           1                                  0  0.890880
# 1739                           0                                  2  0.429661
# 1740                           0                                 76  2.676694
# 1741                           4                                  0  0.454628
#
# [1742 rows x 8 columns]

# %%
recommendation_results_final.loc[recommendation_results_final['uid'] == 'C95823']
# Out:
#          uid     iid  rui       est                    details  \
# 790   C95823  P19760  4.0  2.561113  {'was_impossible': False}
# 1025  C95823  P23134  1.0  3.049320  {'was_impossible': False}
#
#       No. of items rated by user  No. of users that rated this item     error
# 790                            1                                  2  1.438887
# 1025                           1                                  0  2.049320

# %%
recommendation_results_final.rename(columns={'iid':'productId'}, inplace=True)

# %%
recommendation_results_final = pd.merge(recommendation_results1, new, on='productId', how='left')

# %%
recommendation_results_final.rename(columns={'iid':'productId','rui':'Actual Rating','est':'Predicted'}, inplace=True)

# %%
recommendation_results_final.loc[recommendation_results_final['uid'] == 'C95823']
# Out:
#          uid productId  Actual Rating  Predicted                    details  \
# 790   C95823    P19760            4.0   2.561113  {'was_impossible': False}
# 1025  C95823    P23134            1.0   3.049320  {'was_impossible': False}
#
#       No. of items rated by user  No. of users that rated this item     error  \
# 790                            1                                  2  1.438887
# 1025                           1                                  0  2.049320
#
#                                            product_name
# 790                Organic Potato Quinoa & Spinach Soup
# 1025  Baked Scalloped Potatoes With Real Cheddar Che...

# %%
del recommendation_results_final['Actual Rating']
del recommendation_results_final['details']
del recommendation_results_final['error']

# %%
recommendation_results_final
# Out:
#          uid productId  Predicted  No. of items rated by user  \
# 0     C71088    P10025   4.326070                           2
# 1     C88921    P14134   3.242378                           0
# 2     C92824    P28011   4.455684                           1
# 3     C31650    P10696   3.523533                           0
# 4     C61824    P22999   3.493849                           1
# ...      ...       ...        ...                         ...
# 1737  C36446    P01384   4.580790                           1
# 1738  C05429    P03621   3.390880                           1
# 1739  C07393    P25680   2.570339                           0
# 1740  C95427    P03185   3.676694                           0
# 1741  C60720    P21993   4.545372                           4
#
#       No. of users that rated this item  \
# 0                                     0
# 1                                     1
# 2                                    84
# 3                                     1
# 4                                     6
# ...                                 ...
# 1737                                 18
# 1738                                  0
# 1739                                  2
# 1740                                 76
# 1741                                  0
#
#                                            product_name
# 0                  Noodle Soup, Shin Cup, Gourmet Spicy
# 1     Flatbread Pizza All Natural Tomato Sauce Pizza...
# 2                         Clotted Cream, English Luxury
# 3                            Organic Raisin Bran Cereal
# 4                                   Vanilla Coconutmilk
# ...                                                 ...
# 1737                Yours Truly Chocolate Covered Cones
# 1738                       Parmigiano Reggiano Marinara
# 1739                          Premium Pork Sage Sausage
# 1740  Crystals Lavender Blossom In-Wash Fragrance Bo...
# 1741                   Boneless Skinless Chicken Breast
#
# [1742 rows x 6 columns]

# %%
recommendation_results_final1 = recommendation_results_final.copy()

# %%
del recommendation_results_final1['No. of items rated by user']
del recommendation_results_final1['No. of users that rated this item']

# %% [markdown]
# # Display of recommendation results

# %%
recommendation_results_final1
# Out:
#          uid productId  Predicted  \
# 0     C71088    P10025   4.326070
# 1     C88921    P14134   3.242378
# 2     C92824    P28011   4.455684
# 3     C31650    P10696   3.523533
# 4     C61824    P22999   3.493849
# ...      ...       ...        ...
# 1737  C36446    P01384   4.580790
# 1738  C05429    P03621   3.390880
# 1739  C07393    P25680   2.570339
# 1740  C95427    P03185   3.676694
# 1741  C60720    P21993   4.545372
#
#                                            product_name
# 0                  Noodle Soup, Shin Cup, Gourmet Spicy
# 1     Flatbread Pizza All Natural Tomato Sauce Pizza...
# 2                         Clotted Cream, English Luxury
# 3                            Organic Raisin Bran Cereal
# 4                                   Vanilla Coconutmilk
# ...                                                 ...
# 1737                Yours Truly Chocolate Covered Cones
# 1738                       Parmigiano Reggiano Marinara
# 1739                          Premium Pork Sage Sausage
# 1740  Crystals Lavender Blossom In-Wash Fragrance Bo...
# 1741                   Boneless Skinless Chicken Breast
#
# [1742 rows x 4 columns]

# %%
recommendation_results_final1.to_pickle('rec_res.pkl')

# %% [markdown]
# # Final Model for first time users

# %%
def find_popular_items(data, n_recs):
    top_n_items = data.product_name.value_counts().sort_values(ascending=False)[:n_recs].index
    return list(top_n_items)

# %%
def popular_in_your_area(data, state, n_recs):
    location_df = data[data.customer_state == state]
    top_n_items = location_df.product_name.value_counts().sort_values(ascending=False)[:n_recs].index
    return list(top_n_items)

# %% [markdown]
# ### The recommendation of the products will be based on the segmentation

# %%
def first_time_recommender(data, uid, n_recs):
    hot_items = find_popular_items(data, n_recs)
    state = data[data.customer_unique_id==uid].customer_state.max()
    popular_in_area = popular_in_your_area(data, state, n_recs)
    
    print(f"Hot items you might like:\n {hot_items}\n")
    print(f"Popular items in your area:\n {popular_in_area}")
    
    recommendation = {'Hot Items': hot_items, 'Area': popular_in_area}
    
    return recommendation

# %%
recommendation = first_time_recommender(full_df, 'C15383', 5)
# Out:
# Hot items you might like:
#  ['Toasted Buttercrisp Crackers', 'Stainless Steel Water Bottle With Sport Cap, Aqua Color', 'Clotted Cream, English Luxury', 'Corn Pops Cereal', '8\\" Pepperoni Pizza']
#
# Popular items in your area:
#  ['Fresh Tomato & Basil Sauce', 'Traditional Non-Alcoholic Egg Nog', 'Sparkling Clementine Juice Beverage', 'Stainless Steel Water Bottle With Sport Cap, Aqua Color', 'Toasted Buttercrisp Crackers']

# %% [markdown]
# ### Thus the above displayed result is a sample of the recommendation to the new users
